# %% [markdown]
# # LOAD package

# %%
# from astropy import table
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
from astropy.table import Table,Column,hstack
from astropy.io import fits

# %% [markdown]
# # LOAD data

# %%
hsc_band = Table.read("./sed_red.fits")

# %%
hsc_band    #221208319
# Out:
# <Table length=221208319>
#     id     redshift  ...      subaru.hsc.y         subaru.hsc.y_err
#   int64    float64   ...        float64                float64
# --------- ---------- ... ---------------------- ----------------------
#         0 0.57887703 ...     0.0123366704210639  0.0004979684017598629
#         1 0.57887703 ...  0.0037887420039623976 0.00046077510342001915
#         2 0.57887703 ...  0.0011051925830543041 0.00042143967584706843
#         3 0.57887703 ...  0.0005335050518624485  0.0005188738577999175
#         4 0.57887703 ...   0.001375172520056367 0.00044905158574692905
#         5 0.57887703 ...   0.005078374408185482  0.0005123354494571686
#         6 0.57887703 ...   0.007644925732165575  0.0003845090977847576
#         7 0.57887703 ...   0.008751287125051022  0.0006671291776001453
#         8 0.57887703 ...  0.0007567027350887656  0.0005924117867834866
#         9 0.57887703 ...  0.0003338636306580156  0.0007234681397676468
# ...

# %%
hsc_pos = Table.read("/home/kunxu/red_disk/PCF/satellite_2.fits")

# %%
hsc_pos    #221208319
# Out:
# <Table length=221208319>
#         ra                dec              mass0p55      ...  photoz skymap_id
#      float64            float64            float64       ... float32   int32
# ------------------ ------------------ ------------------ ... ------- ---------
#  29.11596307549589 -6.775140624839325 10.548685502252493 ...    0.63  82780004
# 29.097010963966863  -6.77468933995016  8.941219268240122 ...    0.52  82780004
# 29.126665626064202  -6.77473359426081  9.080812226388796 ...    0.64  82780004
# 29.067357382379907 -6.774723759969203   8.72573088876492 ...    3.33  82780004
#  29.11473313855873 -6.774551113549213  9.087600550086725 ...    1.17  82780004
# 29.108439423590077 -6.773931553803997 10.042123582553645 ...    0.57  82780004
#  29.10984648746462 -6.773631608498949  8.757954132923972 ...    0.96  82780004
# 29.096387207795175 -6.773254081977553  9.545165047904895 ...    0.45  82780004
# 29.049894596351326 -6.773429459673613  8.354690756434007 ...    0.37  82780004
# ...

# %%
hsc = hstack((hsc_band,hsc_pos))

# %%
hsc   #221208319
# Out:
# <Table length=221208319>
#     id     redshift       subaru.hsc.g      ...  photoz skymap_id
#   int64    float64          float64         ... float32   int32
# --------- ---------- ---------------------- ... ------- ---------
#         0 0.57887703  0.0005001766257919371 ...    0.63  82780004
#         1 0.57887703  0.0010655235964804888 ...    0.52  82780004
#         2 0.57887703  0.0002237337175756693 ...    0.64  82780004
#         3 0.57887703                     -- ...    3.33  82780004
#         4 0.57887703 0.00038711080560460687 ...    1.17  82780004
#         5 0.57887703   0.000346305372659117 ...    0.57  82780004
#         6 0.57887703   0.003838383825495839 ...    0.96  82780004
#         7 0.57887703  0.0014679066371172667 ...    0.45  82780004
#         8 0.57887703  0.0005604822654277086 ...    0.37  82780004
#         9 0.57887703 0.00025065834051929414 ...     0.6  82780004
#       ...        ...                    ... ...     ...       ...
# ...

# %%
hsc.columns
# Out:
# <TableColumns names=('id','redshift','subaru.hsc.g','subaru.hsc.g_err','subaru.hsc.r','subaru.hsc.r_err','subaru.hsc.i','subaru.hsc.i_err','subaru.hsc.z','subaru.hsc.z_err','subaru.hsc.y','subaru.hsc.y_err','ra','dec','mass0p55','mass0p65','g0p55','g0p65','r0p55','r0p65','photoz','skymap_id')>

# %%
hsc1 = hsc['id','subaru.hsc.g','subaru.hsc.g_err',\
          'subaru.hsc.r','subaru.hsc.r_err','subaru.hsc.i','subaru.hsc.i_err',\
           'subaru.hsc.z','subaru.hsc.z_err','subaru.hsc.y','subaru.hsc.y_err',\
           'ra','dec','skymap_id']

# %%
hsc1
# Out:
# <Table length=221208319>
#     id         subaru.hsc.g      ...        dec         skymap_id
#   int64          float64         ...      float64         int32
# --------- ---------------------- ... ------------------ ---------
#         0  0.0005001766257919371 ... -6.775140624839325  82780004
#         1  0.0010655235964804888 ...  -6.77468933995016  82780004
#         2  0.0002237337175756693 ...  -6.77473359426081  82780004
#         3                     -- ... -6.774723759969203  82780004
#         4 0.00038711080560460687 ... -6.774551113549213  82780004
#         5   0.000346305372659117 ... -6.773931553803997  82780004
#         6   0.003838383825495839 ... -6.773631608498949  82780004
#         7  0.0014679066371172667 ... -6.773254081977553  82780004
#         8  0.0005604822654277086 ... -6.773429459673613  82780004
#         9 0.00025065834051929414 ... -6.773342043991594  82780004
#       ...                    ... ...                ...       ...
# ...

# %% [markdown]
# # 除去 satellite部分

# %%
star = fits.getdata('/home/kunxu/red_disk/PCF/star_flag_sort.fits', 1)

# %%
star['z_extendedness_value']
# Out:
# array([1., 1., 1., ..., 1., 0., 1.])

# %%
hsc_new = hsc1[star['z_extendedness_value']==1]

# %%
hsc_new   #174900944
# Out:
# <Table length=174900944>
#     id         subaru.hsc.g      ...        dec         skymap_id
#   int64          float64         ...      float64         int32
# --------- ---------------------- ... ------------------ ---------
#         0  0.0005001766257919371 ... -6.775140624839325  82780004
#         1  0.0010655235964804888 ...  -6.77468933995016  82780004
#         2  0.0002237337175756693 ...  -6.77473359426081  82780004
#         3                     -- ... -6.774723759969203  82780004
#         4 0.00038711080560460687 ... -6.774551113549213  82780004
#         5   0.000346305372659117 ... -6.773931553803997  82780004
#         6   0.003838383825495839 ... -6.773631608498949  82780004
#         7  0.0014679066371172667 ... -6.773254081977553  82780004
#         8  0.0005604822654277086 ... -6.773429459673613  82780004
#         9 0.00025065834051929414 ... -6.773342043991594  82780004
#       ...                    ... ...                ...       ...
# ...

# %%
hsc_new.columns
# Out:
# <TableColumns names=('id','subaru.hsc.g','subaru.hsc.g_err','subaru.hsc.r','subaru.hsc.r_err','subaru.hsc.i','subaru.hsc.i_err','subaru.hsc.z','subaru.hsc.z_err','subaru.hsc.y','subaru.hsc.y_err','ra','dec','skymap_id')>

# %%
Table(hsc_new).write("./hsc_band.fits")

# %%
pwd
# Out:
# '/home/yunzheng/PAC/code/hsc_SEDfitting'
