# %% [markdown]
# # LOAD package

# %%
# %pylab
from astropy.table import Table
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib
# /home/yunzheng/.local/anaconda/envs/mynumba/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['gamma', 'trapz', 'f', 'number']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.interpolate import interp1d
from scipy.integrate import quad,trapz
from scipy.special import gamma
from scipy.optimize import curve_fit

# %%
import seaborn as sns
sns.set()
# sns.set(rc={'figure.figsize':(15.7,9.27)})
# sns.set_style("ticks")

# %% [markdown]
# # LOAD data

# %% [markdown]
# ## total nwp

# %% [markdown]
# ### 直接观测得到的N

# %%
cen_bin = [11.4, 11.6, 11.8]
sate_bin = [9.0, 9.5, 10.0, 10.5,11.0]
rvir = np.array([643.4968999301032,788.7737148534878 ])/1000

# %%
np.searchsorted?
# Out:
# Signature: np.searchsorted(a, v, side='left', sorter=None)
# Docstring:
# Find indices where elements should be inserted to maintain order.
#
# Find the indices into a sorted array `a` such that, if the
# corresponding elements in `v` were inserted before the indices, the
# order of `a` would be preserved.
#
# Assuming that `a` is sorted:
#
# ======  ============================
# `side`  returned index `i` satisfies
# ======  ============================
# left    ``a[i-1] < v <= a[i]``
# right   ``a[i-1] <= v < a[i]``
# ======  ============================
#
# Parameters
# ----------
# a : 1-D array_like
#     Input array. If `sorter` is None, then it must be sorted in
#     ascending order, otherwise `sorter` must be an array of indices
#     that sort it.
# v : array_like
#     Values to insert into `a`.
# side : {'left', 'right'}, optional
#     If 'left', the index of the first suitable location found is given.
#     If 'right', return the last such index.  If there is no suitable
#     index, return either 0 or N (where N is the length of `a`).
# sorter : 1-D array_like, optional
#     Optional array of integer indices that sort array a into ascending
#     order. They are typically the result of argsort.
#
#     .. versionadded:: 1.7.0
#
# Returns
# -------
# indices : array of ints
#     Array of insertion points with the same shape as `v`.
#
# See Also
# --------
# sort : Return a sorted copy of an array.
# histogram : Produce histogram from 1-D data.
#
# Notes
# -----
# Binary search is used to find the required insertion points.
#
# As of NumPy 1.4.0 `searchsorted` works with real/complex arrays containing
# `nan` values. The enhanced sort order is documented in `sort`.
#
# This function uses the same algorithm as the builtin python `bisect.bisect_left`
# (``side='left'``) and `bisect.bisect_right` (``side='right'``) functions,
# which is also vectorized in the `v` argument.
#
# Examples
# --------
# >>> np.searchsorted([1,2,3,4,5], 3)
# 2
# >>> np.searchsorted([1,2,3,4,5], 3, side='right')
# 3
# >>> np.searchsorted([1,2,3,4,5], [-10, 10, 2, 3])
# array([0, 5, 1, 2])
# File:      ~/.local/anaconda/envs/mynumba/lib/python3.8/site-packages/numpy/core/fromnumeric.py
# Type:      function

# %%
r = np.logspace(-2, 2, 21)
r = r[4:]
r_need = 10**((np.log10(r[1:])+np.log10(r[:-1]))/2.0)
# r_need = r_need[4:-2]
number = np.zeros((2,4))

for i in range(len(cen_bin)-1):
    for j in range(len(sate_bin)-1):
        data = np.load("/home/yunzheng/PAC/code/PAC/0_0.2/sdss_PAC/%.1f_%.1f.npy"%(cen_bin[i],sate_bin[j]),allow_pickle=True)
        index = np.searchsorted(r,rvir[i])
#         print("The index:",index)      #6
#         print("The r :",r[index])  #1.0

        rp_new = np.hstack((r[1:index],rvir[i]))
#         print("The rp:",rp_new)
        r_need_new = r_need[1:index]
#         print("The rneed new",r_need_new)
        nwp_new = data[1][1:index]



        r_inter = (np.log10(rp_new[-1])+np.log10(rp_new[-2]))/2.0
        print("The inter r:",r_inter)

        
        r_need_inter = np.array([np.log10(r_need_new[-2]),np.log10(r_need_new[-1])])
        print("the inter rneed bin:",r_need_inter)

        
        nwp_inter = np.array([np.log10(nwp_new[-2]),np.log10(nwp_new[-1])])
        print("the nwp interbin:",10**nwp_inter)

        
        f = interp1d(r_need_inter,nwp_inter)
        nwp_inter0 = f(r_inter)
        nwp_new = np.hstack((nwp_new[:-1],10**nwp_inter0))
        print("The nwp_inter:",10**nwp_inter0)

        
        print("the nwp_new:")
        print(nwp_new)
        N = np.zeros(len(rp_new)-1)
        print("The number for each bin:")
        for k in range(len(rp_new)-1):
            N[k] = np.pi * (rp_new[k+1]**2-rp_new[k]**2) * nwp_new[k]
            print(N[k])
        print("The total number:")
        print(np.sum(N)) 
        number[i][j] = np.sum(N)
        
np.save("./all/original_num2.npy",number)
# Out:
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21263139 1.1280089 ]
# The nwp_inter: 1.5572528550297455
# the nwp_new:
# [7.3033171  5.12528399 3.59928519 2.21263139 1.55725286]
# The number for each bin:
# 0.34688793866751266
# 0.6114866451225076
# 1.0786618056384265
# 1.6656283749304979
# 0.07818355190745839
# The total number:
# 3.780848316266403
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.90231027 1.48025354]
# The nwp_inter: 2.043112808209821
# the nwp_new:
# [12.80349565  8.29585668  4.68147244  2.90231027  2.04311281]
# The number for each bin:
# 0.6081316413439607
# 0.9897608758032768
# 1.4029801076909838
# 2.1848060012972628
# 0.10257667261776472
# The total number:
# 5.288255298753249
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60732591 1.35970125]
# The nwp_inter: 1.8568554238929493
# the nwp_new:
# [10.76476478  7.26992299  4.31337076  2.60732591  1.85685542]
# The number for each bin:
# 0.5112974029473724
# 0.8673589272409855
# 1.2926645310869287
# 1.9627471816047242
# 0.09322542061790409
# The total number:
# 4.727293463497915
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21709547 0.59319668]
# The nwp_inter: 0.8367442778182183
# the nwp_new:
# [4.71781618 2.88984826 2.00614729 1.21709547 0.83674428]
# The number for each bin:
# 0.22408359192884567
# 0.34478160119303985
# 0.6012178393689139
# 0.9162071775507218
# 0.04200964504047729
# The total number:
# 2.1282998550819983
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.15583621 1.86305664]
# The nwp_inter: 2.133988337180451
# the nwp_new:
# [11.66428687  7.26023901  4.89140922  3.15583621  2.13398834]
# The number for each bin:
# 0.5540222850627943
# 0.8662035517662565
# 1.4658955945108554
# 2.375655684493596
# 1.5021041587470936
# The total number:
# 6.763881274580596
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [4.57097659 2.12716647]
# The nwp_inter: 2.5905049264177102
# the nwp_new:
# [21.67115792 12.65653376  7.41824932  4.57097659  2.59050493]
# The number for each bin:
# 1.0293217720062282
# 1.5100239099342971
# 2.22315870890667
# 3.4409474428264155
# 1.823443997059593
# The total number:
# 10.026895830733205
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.69614842 2.14273453]
# The nwp_inter: 2.465855613754987
# the nwp_new:
# [19.92274335 11.6785172   7.32212432  3.69614842  2.46585561]
# The number for each bin:
# 0.9462767778948068
# 1.3933388505562385
# 2.194351221161966
# 2.782392821551931
# 1.7357039435300454
# The total number:
# 9.052063614694987
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.91442374 0.96669268]
# The nwp_inter: 1.1527543039601635
# the nwp_new:
# [6.2414118  5.63897871 3.07601901 1.91442374 1.1527543 ]
# The number for each bin:
# 0.29645029036804804
# 0.6727744609835803
# 0.9218453236265869
# 1.4411431238036165
# 0.8114182274679187
# The total number:
# 4.14363142624975

# %%
number
# Out:
# array([[ 3.78084832,  5.2882553 ,  4.72729346,  2.12829986],
#        [ 6.76388127, 10.02689583,  9.05206361,  4.14363143]])

# %% [markdown]
# ### 计算修正比例

# %%
nwp[0][:6]
# Out:
# array([0.07943282, 0.12589254, 0.19952623, 0.31622777, 0.50118723,
#        0.79432823])

# %%
r_need0[:10]
# Out:
# array([0.01258925, 0.01995262, 0.03162278, 0.05011872, 0.07943282,
#        0.12589254, 0.19952623, 0.31622777, 0.50118723, 0.79432823])

# %%
r_need0[:5]
# Out:
# array([0.01258925, 0.01995262, 0.03162278, 0.05011872, 0.07943282])

# %%
nwp[0][1:6]
# Out:
# array([0.12589254, 0.19952623, 0.31622777, 0.50118723, 0.79432823])

# %%
r0 = np.logspace(-2, 2, 21)
# r = r[4:]
r_need0 = 10**((np.log10(r0[1:])+np.log10(r0[:-1]))/2.0)
number_new = np.zeros((2,4))
color = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

for i in range(1):
    for j in range(len(sate_bin)-1):
        nwp = np.load("/home/yunzheng/PAC/code/PAC/0_0.2/sdss_PAC/%.1f_%.1f.npy"%(cen_bin[i],sate_bin[j]),allow_pickle=True)
        
        def func_wp(rp,r1,gam):
            y = rp**(1-gam)*r1**gam*gamma(0.5)*gamma(0.5*(gam-1))/gamma(0.5*gam)
            return y
        
        
        popt,pcov = curve_fit(func_wp,nwp[0][1:7],nwp[1][1:7],sigma = nwp[2][1:7],p0=(5,2.05))
        print(popt)
        perr = np.sqrt(np.diag(pcov))
#         print(perr)
        
#         plt.plot(nwp[0],nwp[1],color = color[j])
#         plt.plot(r_need0[:11],func_wp(r_need0[:11],*popt),color = color[j])
#         plt.xscale("log")
#         plt.yscale("log")
#         plt.xlim(0.01,10)
#         plt.ylim(0.1,1000)
        
        
        def part_wp1(r,rp0,r1,gam):
            y = 2*r1**gam*r**(1-gam)*(r**2 - rp0**2)**(-0.5)
            return y
        
        def func_wp1(rp,rvir0,r1,gam):
            y = quad(part_wp1,rp,rvir0,args = (rp,r1,gam))
            return y
        

##############calculate ratio###########
        nwp_new = func_wp(r_need0[:5],*popt)
        index = np.searchsorted(r0,rvir[i])
#         print("The index:",index)      #10


        nwp_new = np.hstack((nwp_new,nwp[1][1:index-4]))
#         print("The nwp_new:",nwp_new)
        rp_new = np.hstack((r0[:index],rvir[i]))
        r_need_new = r_need0[:index]
        print(r_need_new)


        r_inter = (np.log10(rp_new[-1])+np.log10(rp_new[-2]))/2.0
        print("The inter r:",r_inter)

        
        r_need_inter = np.array([np.log10(r_need_new[-2]),np.log10(r_need_new[-1])])
        print("the inter rneed bin:",r_need_inter)

        
        nwp_inter = np.array([np.log10(nwp_new[-2]),np.log10(nwp_new[-1])])
        print("the nwp interbin:",10**nwp_inter)

        
#         f = interp1d(r_need_inter,nwp_inter,fill_value ='extrapolate')
#         nwp_inter0 = f(r_inter)
#         nwp_new = np.hstack((nwp_new[:-1],10**nwp_inter0))
#         print("The nwp_inter:",10**nwp_inter0)


#         N = np.zeros(len(rp_new)-1)
#         for k in range(len(rp_new)-1):
#             ratio_corr = (func_wp1(rp_new[k],rvir[i],popt[0],popt[1])[0])/func_wp(rp_new[k],popt[0],popt[1])
#             print("The corr ratio:")
#             print(ratio_corr)
#             N[k] = np.pi * (rp_new[k+1]**2-rp_new[k]**2) * nwp_new[k] * ratio_corr

#         number_new[i][j] = np.sum(N)
# # np.save("./all/corr_num2.npy",number_new)
# Out:
# [0.56236571 2.02490825]
# The original nwp: [10.92699467  7.3033171   5.12528399  3.59928519  2.21263139  1.1280089 ]
# The nwp_new: [85.28984278 53.20049388 33.18440341 20.69914298 12.91132207  7.3033171
#   5.12528399  3.59928519  2.21263139  1.1280089 ]
# [0.66229188 2.21526251]
# The original nwp: [19.23073768 12.80349565  8.29585668  4.68147244  2.90231027  1.48025354]
# The nwp_new: [224.9507196  128.53899046  73.44840726  41.96912167  23.98155711
#   12.80349565   8.29585668   4.68147244   2.90231027   1.48025354]
# [0.63292023 2.16700774]
# The original nwp: [16.78987187 10.76476478  7.26992299  4.31337076  2.60732591  1.35970125]
# The nwp_new: [173.04366557 101.10069915  59.06804699  34.51048513  20.16273848
#   10.76476478   7.26992299   4.31337076   2.60732591   1.35970125]
# [0.43513357 2.1200406 ]
# The original nwp: [6.344762   4.71781618 2.88984826 2.00614729 1.21709547 0.59319668]
# The nwp_new: [66.8842147  39.93148962 23.84006257 14.23309245  8.49749954  4.71781618
#   2.88984826  2.00614729  1.21709547  0.59319668]

# %%
number_new
# Out:
# array([[2.62560317, 3.9832001 , 3.50025542, 1.54116284],
#        [4.66514509, 7.63490925, 6.9414182 , 2.95847517]])

# %%
number
# Out:
# array([[ 5.34161313,  3.47869608,  2.72303283,  1.76803182],
#        [10.19322937,  6.59853485,  5.050862  ,  3.54573777]])

# %%
number_new / number
# Out:
# array([[0.69444816, 0.7532163 , 0.7404354 , 0.72412862],
#        [0.68971422, 0.76144296, 0.76683268, 0.71398126]])

# %% [markdown]
# ## LOAD each field nwp

# %%
r = np.logspace(-2, 2, 21)
r = r[4:]
r_need = 10**((np.log10(r[1:])+np.log10(r[:-1]))/2.0)

m_sate = [9.0,9.5,10.0,10.5,11.0]
m_cen = [11.4,11.6,11.8]

jack=50
zs = ['0p075','0p125','0p175']

num0 = np.load("./all/original_num2.npy")
num1 = np.load("./all/corr_num2.npy")
fq_original = num1/num0


number = np.zeros((2,4,50))
for i in range(len(cen_bin)-1):
    for j in range(len(sate_bin)-1):
        
        pcf = np.zeros((jack,len(r_need)))
        para1 = 0
        for k in range(len(zs)):
            data = np.load('/home/yunzheng/PAC/code/PAC/0_0.2/sdss_PAC/%s_%.1f_%.1f_results_jack.npy' % (zs[k],m_cen[i],m_sate[j]))
            para = np.load('/home/yunzheng/PAC/code/PAC/0_0.2/sdss_PAC/%s_%.1f_%.1f_param_jack.npy' % (zs[k],m_cen[i],m_sate[j]))


            pcf += (data * para)
            para1 += para

        pcf = pcf / para1
        
        
        for q in range(50):
            
            index = np.searchsorted(r,rvir[i])-1
            print("The index rvir:")
            print(index)
            print(r[index])


        
            nwp_new = pcf[q][1:index+1]
            rp_new = np.hstack((r[1:index+1],rvir[i]))
            r_need_new = r_need[1:index+1]
    #         print(r_need_new)


            r_inter = (np.log10(rp_new[-1])+np.log10(rp_new[-2]))/2.0
            print("The inter r:",r_inter)


            r_need_inter = np.array([np.log10(r_need_new[-2]),np.log10(r_need_new[-1])])
            print("the inter rneed bin:",r_need_inter)


            nwp_inter = np.array([np.log10(nwp_new[-2]),np.log10(nwp_new[-1])])
            print("the nwp interbin:",10**nwp_inter)


            f = interp1d(r_need_inter,nwp_inter)
            nwp_inter0 = f(r_inter)
            nwp_new = np.hstack((nwp_new[:-1],10**nwp_inter0))
            print("The nwp_inter:",10**nwp_inter0)


            N = np.zeros(len(rp_new)-1)
            for p in range(len(rp_new)-1):
                N[p] = np.pi * (rp_new[p+1]**2-rp_new[p]**2) * nwp_new[p] * fq_original[i][j]

            print("The total number:")
            print(np.sum(N))
            
            number[i][j][q] = np.sum(N)
np.save("./all/eachfield_result2.npy",number)
# Out:
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22621091 1.13480216]
# The nwp_inter: 1.5667168292068248
# The total number:
# 2.653389954204522
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22210925 1.12989215]
# The nwp_inter: 1.5617997712249845
# The total number:
# 2.650688642227391
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.23572712 1.16287611]
# The nwp_inter: 1.5900492830267905
# The total number:
# 2.6500726221484934
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20293644 1.13551158]
# The nwp_inter: 1.5593635139725688
# The total number:
# 2.613148191534616
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19800798 1.12011899]
# The nwp_inter: 1.5466478791737306
# The total number:
# 2.6138197556898386
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22809763 1.13865417]
# The nwp_inter: 1.5701237796306708
# The total number:
# 2.6495182718966572
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.2264121  1.14623329]
# The nwp_inter: 1.5749933663694358
# The total number:
# 2.6435231033088904
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18689948 1.11432218]
# The nwp_inter: 1.538733488532053
# The total number:
# 2.6043615183554514
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.2024413  1.11349946]
# The nwp_inter: 1.5433634729103354
# The total number:
# 2.618865205092444
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20796184 1.10554821]
# The nwp_inter: 1.5394512340644455
# The total number:
# 2.6123096873827993
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.2216692  1.13195656]
# The nwp_inter: 1.563138675097812
# The total number:
# 2.642131475469045
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.2132261  1.13295882]
# The nwp_inter: 1.5610126778879283
# The total number:
# 2.6306686280959477
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21766928 1.12438964]
# The nwp_inter: 1.5563390760327662
# The total number:
# 2.6274588389629434
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21160992 1.11876525]
# The nwp_inter: 1.5502438598847017
# The total number:
# 2.6169524616208633
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20514169 1.131346  ]
# The nwp_inter: 1.5571239560233894
# The total number:
# 2.6114371931320766
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.1910665  1.13297097]
# The nwp_inter: 1.553520972998687
# The total number:
# 2.6059971659600407
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19668911 1.1118134 ]
# The nwp_inter: 1.5402155225832095
# The total number:
# 2.600774432777413
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20557574 1.1232215 ]
# The nwp_inter: 1.551430062966194
# The total number:
# 2.6167337625157625
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21388973 1.12043589]
# The nwp_inter: 1.5522156432667302
# The total number:
# 2.6244054203674714
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20636085 1.12316065]
# The nwp_inter: 1.5516505326456755
# The total number:
# 2.6102376836568575
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.1987652  1.12608536]
# The nwp_inter: 1.5511932984585235
# The total number:
# 2.6147242779473174
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22532534 1.12781899]
# The nwp_inter: 1.561385535783141
# The total number:
# 2.631005130365718
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20331218 1.11158893]
# The nwp_inter: 1.5422740879689605
# The total number:
# 2.609857973877423
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18336757 1.13363881]
# The nwp_inter: 1.551382400434629
# The total number:
# 2.5943162571680594
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19769511 1.11743687]
# The nwp_inter: 1.5446106747187989
# The total number:
# 2.6108085594354535
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19580332 1.11396946]
# The nwp_inter: 1.5414744370834061
# The total number:
# 2.606371391709806
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21251123 1.12908433]
# The nwp_inter: 1.5579862351777416
# The total number:
# 2.6283908874359083
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22248435 1.11828643]
# The nwp_inter: 1.5535408196315508
# The total number:
# 2.631658319308798
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20129987 1.12757668]
# The nwp_inter: 1.5531202189296986
# The total number:
# 2.6227963414787254
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19166771 1.12059906]
# The nwp_inter: 1.5448559874850727
# The total number:
# 2.6104700423527647
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21939886 1.13371794]
# The nwp_inter: 1.5636409528624986
# The total number:
# 2.6181676050301377
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.23410869 1.14293799]
# The nwp_inter: 1.5752307834238253
# The total number:
# 2.6430889873833916
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19558649 1.12576884]
# The nwp_inter: 1.5498923688122752
# The total number:
# 2.6098571902366055
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22538208 1.14395626]
# The nwp_inter: 1.573012919635994
# The total number:
# 2.645683002340558
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21441685 1.12632049]
# The nwp_inter: 1.556638024219895
# The total number:
# 2.6197883544267957
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20842927 1.13755602]
# The nwp_inter: 1.5626881795021568
# The total number:
# 2.631345982388972
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21120023 1.11876023]
# The nwp_inter: 1.5501027715798192
# The total number:
# 2.623054965589315
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22093901 1.12500535]
# The nwp_inter: 1.5578815474393697
# The total number:
# 2.6180925868022293
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18826237 1.11498038]
# The nwp_inter: 1.5396663330608886
# The total number:
# 2.5981295433727847
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20499179 1.11835352]
# The nwp_inter: 1.5477246790224415
# The total number:
# 2.6073191270418863
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21208224 1.11618228]
# The nwp_inter: 1.5485350393694168
# The total number:
# 2.6311154955165965
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19607608 1.12768148]
# The nwp_inter: 1.5514302340043806
# The total number:
# 2.606729085138026
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.1797298  1.09385183]
# The nwp_inter: 1.5215373264590089
# The total number:
# 2.583701282019597
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.25207015 1.14218707]
# The nwp_inter: 1.5807379552091598
# The total number:
# 2.654788882409644
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19854637 1.12128055]
# The nwp_inter: 1.5476652835184148
# The total number:
# 2.6197754442217165
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19626046 1.12583002]
# The nwp_inter: 1.5501639867640724
# The total number:
# 2.6315160967763096
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19291105 1.1215574 ]
# The nwp_inter: 1.5459642548181245
# The total number:
# 2.595020016211426
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.27564401 1.16622959]
# The nwp_inter: 1.605983813988319
# The total number:
# 2.6872604745490523
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.26420639 1.16003362]
# The nwp_inter: 1.5976718892687873
# The total number:
# 2.688921123567031
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.28939306 1.15969208]
# The nwp_inter: 1.6059071919936898
# The total number:
# 2.7098886896230594
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.90841338 1.52265846]
# The nwp_inter: 2.0755073896149527
# The total number:
# 4.019131115648803
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89531073 1.51365743]
# The nwp_inter: 2.0646347729444265
# The total number:
# 4.006496651705026
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.95447715 1.50983754]
# The nwp_inter: 2.0819779165637122
# The total number:
# 4.033408725845971
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89088634 1.48006062]
# The nwp_inter: 2.0391211113848717
# The total number:
# 3.970768845437406
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.91393394 1.46808923]
# The nwp_inter: 2.0382375287819583
# The total number:
# 3.9850658258165796
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.95621964 1.5147318 ]
# The nwp_inter: 2.0860824573593004
# The total number:
# 4.032438169465849
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.90705987 1.48864409]
# The nwp_inter: 2.0507469603235227
# The total number:
# 3.99011379544177
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89884049 1.4920158 ]
# The nwp_inter: 2.0503867432834713
# The total number:
# 3.975599424442322
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.86908671 1.46421621]
# The nwp_inter: 2.0203777118197044
# The total number:
# 3.9556403148860055
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.87845626 1.44491447]
# The nwp_inter: 2.009581510940039
# The total number:
# 3.9588128499194055
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.90404465 1.47951735]
# The nwp_inter: 2.0431671151578956
# The total number:
# 3.994037190778668
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.92519805 1.48369418]
# The nwp_inter: 2.0532926920250256
# The total number:
# 3.9970453483449173
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.90711544 1.4809251 ]
# The nwp_inter: 2.045214760249997
# The total number:
# 3.972216694240617
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.90196579 1.47843689]
# The nwp_inter: 2.041689143013531
# The total number:
# 3.98464020256399
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.87494896 1.46016496]
# The nwp_inter: 2.0194332720450547
# The total number:
# 3.940756461468911
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89296233 1.48803538]
# The nwp_inter: 2.0455447259723805
# The total number:
# 3.9674143018498915
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89779579 1.45873458]
# The nwp_inter: 2.0260630744648847
# The total number:
# 3.967202910823232
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89315755 1.47855857]
# The nwp_inter: 2.0388081438756744
# The total number:
# 3.9703223432577333
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89691891 1.4857972 ]
# The nwp_inter: 2.0452775470359734
# The total number:
# 3.9751757412877393
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.88773257 1.48028434]
# The nwp_inter: 2.038216669036521
# The total number:
# 3.9593425743148885
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.88889371 1.47797469]
# The nwp_inter: 2.0369499179202104
# The total number:
# 3.9657633778411974
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.91136839 1.48281446]
# The nwp_inter: 2.048007225808005
# The total number:
# 3.986217279904112
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.88287124 1.46137421]
# The nwp_inter: 2.0229677785445648
# The total number:
# 3.9670429485051937
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89750983 1.48235248]
# The nwp_inter: 2.0430033717001606
# The total number:
# 3.966391491683952
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89327043 1.47271847]
# The nwp_inter: 2.0346435970751777
# The total number:
# 3.970258307276227
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.8830136  1.47153456]
# The nwp_inter: 2.0303365621181517
# The total number:
# 3.9526501348395477
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.88209713 1.46690803]
# The nwp_inter: 2.0266975164583605
# The total number:
# 3.9690837408989776
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.88731735 1.47331008]
# The nwp_inter: 2.0330644419769683
# The total number:
# 3.968321256709461
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.90817815 1.47035054]
# The nwp_inter: 2.037944212879039
# The total number:
# 3.9926070040774815
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.86565109 1.47120212]
# The nwp_inter: 2.0242364371399493
# The total number:
# 3.959379630799956
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.9039754  1.47773874]
# The nwp_inter: 2.0418628530350293
# The total number:
# 3.970301982055298
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.93176063 1.48815923]
# The nwp_inter: 2.0587189926132505
# The total number:
# 4.011166394099227
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.88285846 1.46687352]
# The nwp_inter: 2.0269288869428186
# The total number:
# 3.964642139462393
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.90993009 1.4838987 ]
# The nwp_inter: 2.0483033282331364
# The total number:
# 3.9974996033851284
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89373179 1.45582369]
# The nwp_inter: 2.022595091036971
# The total number:
# 3.9649503977978364
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89681879 1.47208346]
# The nwp_inter: 2.035379847772028
# The total number:
# 3.9878579282575823
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.9039738  1.46143667]
# The nwp_inter: 2.0300871869562447
# The total number:
# 3.989885452396142
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89126668 1.47288428]
# The nwp_inter: 2.0340884196152476
# The total number:
# 3.968005562185405
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89860995 1.47148331]
# The nwp_inter: 2.035549318320242
# The total number:
# 3.986756516453755
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.85390921 1.46089689]
# The nwp_inter: 2.0128719282237895
# The total number:
# 3.954885043544076
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.91148055 1.46814144]
# The nwp_inter: 2.0374537429843866
# The total number:
# 3.96850204848047
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.87057009 1.47005778]
# The nwp_inter: 2.0250770688623088
# The total number:
# 3.942472733669956
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.86473552 1.43660958]
# The nwp_inter: 1.9989744011394561
# The total number:
# 3.922347530074299
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.94118318 1.50845428]
# The nwp_inter: 2.0764962230019868
# The total number:
# 4.00126958294322
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.92583809 1.48067727]
# The nwp_inter: 2.0513296581661877
# The total number:
# 3.9933778780574576
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.90013284 1.48313294]
# The nwp_inter: 2.0444493461323434
# The total number:
# 4.000516915121347
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.89658468 1.47584715]
# The nwp_inter: 2.038012480625203
# The total number:
# 3.9698394409014726
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.95987112 1.50935156]
# The nwp_inter: 2.0834466409302164
# The total number:
# 4.063746555275628
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.93361078 1.50942954]
# The nwp_inter: 2.0746346176955757
# The total number:
# 4.041091100713
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.98997616 1.5561831 ]
# The nwp_inter: 2.1271818545739496
# The total number:
# 4.107508357632231
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.64032871 1.38679674]
# The nwp_inter: 1.88738485047252
# The total number:
# 3.5476981130096203
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.6026223  1.38042222]
# The nwp_inter: 1.869938501573956
# The total number:
# 3.5109601393556336
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.62896476 1.40472501]
# The nwp_inter: 1.8961483570590179
# The total number:
# 3.521175448354545
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.6034639  1.37365229]
# The nwp_inter: 1.8654402670674588
# The total number:
# 3.4961763947528453
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60635095 1.34669932]
# The nwp_inter: 1.8472461209868403
# The total number:
# 3.4900730779842917
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.63937356 1.37560476]
# The nwp_inter: 1.879102595680636
# The total number:
# 3.539674837948304
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.5906372  1.35894744]
# The nwp_inter: 1.8506221248829937
# The total number:
# 3.4856092369316714
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.59315354 1.35587811]
# The nwp_inter: 1.8493008585241981
# The total number:
# 3.487354407233299
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.57485759 1.3444533 ]
# The nwp_inter: 1.8349311847380638
# The total number:
# 3.473756586036372
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.59812624 1.33689214]
# The nwp_inter: 1.8374384990979904
# The total number:
# 3.4865022713281695
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.62084156 1.36384115]
# The nwp_inter: 1.8644090138555105
# The total number:
# 3.5043872482898726
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.61111928 1.36970823]
# The nwp_inter: 1.8652653483491701
# The total number:
# 3.502905155485817
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.61503146 1.35523786]
# The nwp_inter: 1.8562950673071716
# The total number:
# 3.4941986412811437
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60966398 1.36262239]
# The nwp_inter: 1.8597318782697223
# The total number:
# 3.5034912365561715
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.57580139 1.34597132]
# The nwp_inter: 1.8363331443098798
# The total number:
# 3.4678010864809568
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60062972 1.36120674]
# The nwp_inter: 1.855641683592227
# The total number:
# 3.491201269199999
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.59490846 1.35182796]
# The nwp_inter: 1.8470167179308425
# The total number:
# 3.4879438749437135
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.57981717 1.34586337]
# The nwp_inter: 1.837626036912261
# The total number:
# 3.4744432418608144
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.61618697 1.36702652]
# The nwp_inter: 1.8650905268686413
# The total number:
# 3.49270639984772
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.59558894 1.3684771 ]
# The nwp_inter: 1.8590752539831865
# The total number:
# 3.48806507071994
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60083605 1.3708702 ]
# The nwp_inter: 1.8625690171876246
# The total number:
# 3.4848831205410846
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.59741404 1.3603203 ]
# The nwp_inter: 1.8539133462272332
# The total number:
# 3.487797730939487
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60318093 1.3432136 ]
# The nwp_inter: 1.8436775021377343
# The total number:
# 3.4848147997281202
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.59240341 1.35658008]
# The nwp_inter: 1.8495438348029298
# The total number:
# 3.4776932005370895
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.58499723 1.36354379]
# The nwp_inter: 1.8519500225867405
# The total number:
# 3.480084070468083
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60583222 1.34500142]
# The nwp_inter: 1.8458556389852114
# The total number:
# 3.5038428508240873
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60827263 1.34777981]
# The nwp_inter: 1.848670724361235
# The total number:
# 3.4995068615220717
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.5860598  1.34141202]
# The nwp_inter: 1.8365780722825644
# The total number:
# 3.4845433313177208
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60872526 1.3541922 ]
# The nwp_inter: 1.8534051120324684
# The total number:
# 3.501097601877137
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.58453399 1.34726091]
# The nwp_inter: 1.840228885572037
# The total number:
# 3.480902654630699
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.60975686 1.35603912]
# The nwp_inter: 1.8550735904712763
# The total number:
# 3.4952214325211823
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.63737412 1.37202698]
# The nwp_inter: 1.8758723770318897
# The total number:
# 3.5167712079883464
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.59738805 1.35559449]
# The nwp_inter: 1.8505437844326256
# The total number:
# 3.492089216923074
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.61415322 1.36054088]
# The nwp_inter: 1.85977952630986
# The total number:
# 3.5112606168114153
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.5897581  1.34282887]
# The nwp_inter: 1.8388465406525751
# The total number:
# 3.4768717402682543
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.6029877  1.35818627]
# The nwp_inter: 1.8542979431542708
# The total number:
# 3.5056212973285588
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.59449656 1.361829  ]
# The nwp_inter: 1.8539875013248486
# The total number:
# 3.4880279482568968
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.57804887 1.34510408]
# The nwp_inter: 1.836482645072581
# The total number:
# 3.473047998362053
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.61133476 1.35959678]
# The nwp_inter: 1.8581469278959952
# The total number:
# 3.500851137748137
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.61482136 1.346479  ]
# The nwp_inter: 1.8499593008006527
# The total number:
# 3.5066928709214156
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.57679742 1.33339895]
# The nwp_inter: 1.8277083977287707
# The total number:
# 3.4611991216485545
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.57763177 1.36684517]
# The nwp_inter: 1.8517557072505715
# The total number:
# 3.474734563210416
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.57010051 1.31590223]
# The nwp_inter: 1.8129054711981845
# The total number:
# 3.459260283659359
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.63576001 1.37020316]
# The nwp_inter: 1.8740226966519369
# The total number:
# 3.5359010868607936
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.61348272 1.3471686 ]
# The nwp_inter: 1.8499997260394485
# The total number:
# 3.5022630485113977
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.61089918 1.36953824]
# The nwp_inter: 1.8650694030559676
# The total number:
# 3.5156593311059576
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.61544219 1.37069042]
# The nwp_inter: 1.8674405577453503
# The total number:
# 3.5005382429720475
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.65366876 1.37493371]
# The nwp_inter: 1.883487805072868
# The total number:
# 3.5538708061869504
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.69663279 1.38194695]
# The nwp_inter: 1.9030638019224249
# The total number:
# 3.5869386891451778
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.69603729 1.41018107]
# The nwp_inter: 1.923033558395884
# The total number:
# 3.624628113317314
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.22091303 0.59427362]
# The nwp_inter: 0.8387922944543136
# The total number:
# 1.5578834874616894
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.2275621  0.59746015]
# The nwp_inter: 0.8433236388156705
# The total number:
# 1.552000175354981
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.23163741 0.60633559]
# The nwp_inter: 0.8511813706903584
# The total number:
# 1.5584432222077902
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20020997 0.58969151]
# The nwp_inter: 0.8286035103155224
# The total number:
# 1.5328791254719039
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20479784 0.58808325]
# The nwp_inter: 0.828936889178025
# The total number:
# 1.5339472296549417
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.22465796 0.60065867]
# The nwp_inter: 0.8447162921186115
# The total number:
# 1.5492436267715353
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21768568 0.59960075]
# The nwp_inter: 0.841637147983304
# The total number:
# 1.5396117881801918
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21264355 0.59431995]
# The nwp_inter: 0.8361021945506671
# The total number:
# 1.5460352711490384
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.2056413  0.58224092]
# The nwp_inter: 0.8249093975560077
# The total number:
# 1.5292740393877424
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21999151 0.5848718 ]
# The nwp_inter: 0.8315466458676074
# The total number:
# 1.5403601886665108
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21626941 0.5932269 ]
# The nwp_inter: 0.836494628343391
# The total number:
# 1.5451089580465416
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21898397 0.60160333]
# The nwp_inter: 0.8435316444545317
# The total number:
# 1.5436556938549646
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.22544679 0.59334266]
# The nwp_inter: 0.8395951407136447
# The total number:
# 1.5418899143857592
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.23094987 0.59280811]
# The nwp_inter: 0.8410023562712833
# The total number:
# 1.5517395253311466
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21658885 0.58160903]
# The nwp_inter: 0.8280172147039021
# The total number:
# 1.5335752228359076
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21079141 0.59182094]
# The nwp_inter: 0.833657274094998
# The total number:
# 1.5328781587015068
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20837312 0.58163321]
# The nwp_inter: 0.8253540135124261
# The total number:
# 1.5341122249203833
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20568062 0.58545776]
# The nwp_inter: 0.8272953427476322
# The total number:
# 1.5326168576994852
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.232679  0.5898318]
# The nwp_inter: 0.839362035025574
# The total number:
# 1.548168418546466
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.22620851 0.59575506]
# The nwp_inter: 0.8416234341080963
# The total number:
# 1.5443752891330569
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21523556 0.59359881]
# The nwp_inter: 0.8364274870445325
# The total number:
# 1.5359449392266808
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.22604934 0.59672135]
# The nwp_inter: 0.8422825275017403
# The total number:
# 1.5433611818516118
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21449354 0.58642155]
# The nwp_inter: 0.8308964457100239
# The total number:
# 1.5388821159058563
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21783542 0.58855462]
# The nwp_inter: 0.833566437628876
# The total number:
# 1.5396370405231332
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21194291 0.59045128]
# The nwp_inter: 0.8330297422879496
# The total number:
# 1.5342465197147264
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21512564 0.59051919]
# The nwp_inter: 0.8341261258045523
# The total number:
# 1.5350455332957929
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20944855 0.58614818]
# The nwp_inter: 0.8290410754670245
# The total number:
# 1.534985486018685
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20364014 0.58879334]
# The nwp_inter: 0.8290769935994825
# The total number:
# 1.5277291501465826
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21887382 0.59107794]
# The nwp_inter: 0.8357686439560508
# The total number:
# 1.543199649467867
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20524943 0.58841757]
# The nwp_inter: 0.8293312914524964
# The total number:
# 1.5324393831128926
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21746054 0.59068741]
# The nwp_inter: 0.8350168820680817
# The total number:
# 1.5410245077293665
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.23113288 0.5987494 ]
# The nwp_inter: 0.8454464972211281
# The total number:
# 1.553039540251305
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21495293 0.59323884]
# The nwp_inter: 0.8360699139342239
# The total number:
# 1.531205741423512
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21571131 0.59964853]
# The nwp_inter: 0.8410186414587022
# The total number:
# 1.5396560328197624
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20365315 0.58629312]
# The nwp_inter: 0.827243909229563
# The total number:
# 1.5327973855440826
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21370704 0.59627033]
# The nwp_inter: 0.8378831036544869
# The total number:
# 1.5455299585055784
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.2182728 0.599153 ]
# The nwp_inter: 0.8415035500493463
# The total number:
# 1.544759063970995
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.19647959 0.58753489]
# The nwp_inter: 0.8257908796296788
# The total number:
# 1.5216055410568154
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20933099 0.59602786]
# The nwp_inter: 0.8362584379234621
# The total number:
# 1.5318507358746418
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21396255 0.5903821 ]
# The nwp_inter: 0.8336429683361685
# The total number:
# 1.5337373329431236
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20486134 0.59489287]
# The nwp_inter: 0.8339484961452911
# The total number:
# 1.5249677699478388
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20647316 0.58580796]
# The nwp_inter: 0.8278136265496813
# The total number:
# 1.52960346514739
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.19908369 0.57935216]
# The nwp_inter: 0.8206280378953446
# The total number:
# 1.5208697873666246
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.23606342 0.60545857]
# The nwp_inter: 0.8520008366287465
# The total number:
# 1.5527862175222085
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.20116048 0.58946021]
# The nwp_inter: 0.8287480019112187
# The total number:
# 1.528955570852018
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21489599 0.59350846]
# The nwp_inter: 0.836249239804858
# The total number:
# 1.5451858732091976
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.21476434 0.5922926 ]
# The nwp_inter: 0.8353123030028199
# The total number:
# 1.5399570593641467
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.25221402 0.60684799]
# The nwp_inter: 0.8583362989443823
# The total number:
# 1.5737848729166604
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.23179229 0.59752238]
# The nwp_inter: 0.8447592256921591
# The total number:
# 1.5668929142225447
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.26319494 0.63137648]
# The nwp_inter: 0.8799222338305788
# The total number:
# 1.5866489921144227
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.1326922  1.86742193]
# The nwp_inter: 2.133649392526878
# The total number:
# 4.686998903257959
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.17052672 1.87557151]
# The nwp_inter: 2.14718850593572
# The total number:
# 4.65806466949053
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.16636005 1.87092242]
# The nwp_inter: 2.1425100533367365
# The total number:
# 4.712260476151063
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.21466849 1.84903397]
# The nwp_inter: 2.132174350320385
# The total number:
# 4.702438722275505
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.19828972 1.87488731]
# The nwp_inter: 2.151433768614248
# The total number:
# 4.710123846091283
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.10952269 1.86416696]
# The nwp_inter: 2.1268165499341154
# The total number:
# 4.621292808418103
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.22747461 1.91988535]
# The nwp_inter: 2.194779600934781
# The total number:
# 4.756795215202864
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.17135704 1.87270653]
# The nwp_inter: 2.1448977840199417
# The total number:
# 4.6940107196079985
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.21062129 1.87424439]
# The nwp_inter: 2.153019469618313
# The total number:
# 4.721292917786525
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.07136126 1.86340951]
# The nwp_inter: 2.119421987121788
# The total number:
# 4.609910639963798
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.13739358 1.84095158]
# The nwp_inter: 2.111971289550922
# The total number:
# 4.611867127265957
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.19224944 1.87213704]
# The nwp_inter: 2.1480440710332345
# The total number:
# 4.700949868345955
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.11845935 1.89215377]
# The nwp_inter: 2.1520656963481377
# The total number:
# 4.6729464094309945
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.08089683 1.82709093]
# The nwp_inter: 2.09034646034748
# The total number:
# 4.609941420706788
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.07217344 1.842464  ]
# The nwp_inter: 2.1018535319521954
# The total number:
# 4.5745316633437385
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.12574758 1.84242011]
# The nwp_inter: 2.11119824559243
# The total number:
# 4.617288674952936
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.19339928 1.86056421]
# The nwp_inter: 2.138376969429387
# The total number:
# 4.686467673323121
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.16591273 1.86304207]
# The nwp_inter: 2.135729216853206
# The total number:
# 4.664708951477337
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.09821039 1.84660692]
# The nwp_inter: 2.109943478372162
# The total number:
# 4.567594397060601
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.17517083 1.83277817]
# The nwp_inter: 2.111506938117117
# The total number:
# 4.661628568880586
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.10748853 1.8497202 ]
# The nwp_inter: 2.1142117621561463
# The total number:
# 4.612782085760854
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.1707148  1.83357755]
# The nwp_inter: 2.111426551636218
# The total number:
# 4.6524487179502545
# The index rvir:
# ...
# The nwp_inter: 2.433338239224275
# The total number:
# 6.8615152942059705
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.73216657 2.1201414 ]
# The nwp_inter: 2.452647043546678
# The total number:
# 6.984379614933609
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.62578274 2.06194016]
# The nwp_inter: 2.3846523970350204
# The total number:
# 6.82121143838192
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.58161025 2.14136875]
# The nwp_inter: 2.444782032531727
# The total number:
# 6.8076760825291975
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.75254078 2.17052999]
# The nwp_inter: 2.4992929917485878
# The total number:
# 7.000100436821543
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.70300112 2.17387468]
# The nwp_inter: 2.493599739576512
# The total number:
# 6.980973783491656
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.65052492 2.13787417]
# The nwp_inter: 2.453837890392977
# The total number:
# 6.918936274520965
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.69839871 2.14627342]
# The nwp_inter: 2.469265499106
# The total number:
# 6.92189733370167
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.67414556 2.12354074]
# The nwp_inter: 2.4456740241728063
# The total number:
# 6.8712200231566225
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.67338263 2.12429717]
# The nwp_inter: 2.4461898716912676
# The total number:
# 6.890565047383596
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.6095177  2.10383787]
# The nwp_inter: 2.4177291802589966
# The total number:
# 6.81923194398956
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.63702866 2.08467772]
# The nwp_inter: 2.4060653985368945
# The total number:
# 6.8555601396804935
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.73694429 2.20111291]
# The nwp_inter: 2.5226807388133197
# The total number:
# 7.002972609481578
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.63743158 2.12940647]
# The nwp_inter: 2.4443551778123744
# The total number:
# 6.878339713357082
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.68668877 2.15676053]
# The nwp_inter: 2.476193122819244
# The total number:
# 6.931287646116019
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.74950349 2.20510109]
# The nwp_inter: 2.5282576238855694
# The total number:
# 7.04577498047272
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.63758937 2.14323206]
# The nwp_inter: 2.4561547236546595
# The total number:
# 6.8763125138160905
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.74886532 2.19247785]
# The nwp_inter: 2.5173946802512708
# The total number:
# 7.024515383994744
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.7071961  2.16814422]
# The nwp_inter: 2.4894442240886803
# The total number:
# 6.967924343805725
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.72439673 2.20550512]
# The nwp_inter: 2.5242287412716102
# The total number:
# 7.0487670919926195
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.69482513 2.14241968]
# The nwp_inter: 2.4653591878477834
# The total number:
# 7.009599123737337
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.71242555 2.19888945]
# The nwp_inter: 2.516517432571362
# The total number:
# 6.999028972888086
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.77156177 2.14868436]
# The nwp_inter: 2.4838275915763064
# The total number:
# 7.024491962008383
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.72583746 2.15972123]
# The nwp_inter: 2.485470482440291
# The total number:
# 6.984036863237421
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.86105931 2.15336398]
# The nwp_inter: 2.50291889434989
# The total number:
# 7.187952896450954
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.98774127 0.98341433]
# The nwp_inter: 1.1788834830971935
# The total number:
# 3.021748339154224
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.89527118 0.96067565]
# The nwp_inter: 1.144455021506651
# The total number:
# 2.935705759020866
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.93874539 0.96474288]
# The nwp_inter: 1.154777327693157
# The total number:
# 2.9760391547311498
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.9109638 0.9836701]
# The nwp_inter: 1.1672060758465195
# The total number:
# 2.9804588132122545
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.92556663 0.96615445]
# The nwp_inter: 1.1540018812455324
# The total number:
# 2.9807664468879174
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.92340623 0.98385314]
# The nwp_inter: 1.1693207076131822
# The total number:
# 2.974840898973531
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.94471291 0.96405748]
# The nwp_inter: 1.1550823801251853
# The total number:
# 2.9854351639252683
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.95149124 0.97836114]
# The nwp_inter: 1.1688282915471506
# The total number:
# 2.9910962931733867
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.93543288 0.97464758]
# The nwp_inter: 1.1630547173917503
# The total number:
# 2.9949372213924024
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.89859563 0.94830805]
# The nwp_inter: 1.1340107558276389
# The total number:
# 2.944966451303814
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87748354 0.95309062]
# The nwp_inter: 1.1349794827094546
# The total number:
# 2.9427212001077363
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.94403497 0.98766915]
# The nwp_inter: 1.1759133017878172
# The total number:
# 2.9935532175378436
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.89716761 0.97586927]
# The nwp_inter: 1.1581634332308761
# The total number:
# 2.957710905595487
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.90209622 0.95158492]
# The nwp_inter: 1.1374581904743426
# The total number:
# 2.901954368839709
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.90907889 0.95951828]
# The nwp_inter: 1.1455715540028897
# The total number:
# 2.941191638203785
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.92611672 0.97883155]
# The nwp_inter: 1.1653097814262814
# The total number:
# 2.95365376983915
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.8702343  0.95354166]
# The nwp_inter: 1.1342472206973426
# The total number:
# 2.936839797984759
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.92834186 0.96075463]
# The nwp_inter: 1.1496367598238606
# The total number:
# 2.959258582635681
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.89886383 0.94816536]
# The nwp_inter: 1.1339253388253436
# The total number:
# 2.9246543231779745
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.92788924 0.9671536 ]
# The nwp_inter: 1.1552464343440518
# The total number:
# 2.9700899149676427
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.92962077 0.98018137]
# The nwp_inter: 1.1670488889548816
# The total number:
# 2.9675402876379913
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.8949843  0.93458142]
# The nwp_inter: 1.1212518743149529
# The total number:
# 2.918794713109004
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.94812891 0.96181607]
# The nwp_inter: 1.1536095402800222
# The total number:
# 2.9773355773591366
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.90560555 1.00023905]
# The nwp_inter: 1.180915621839299
# The total number:
# 2.9639652259914717
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.88435747 0.9649821 ]
# The nwp_inter: 1.1465543873860564
# The total number:
# 2.9309354484024643
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.91281987 0.93547041]
# The nwp_inter: 1.1247547458939362
# The total number:
# 2.9455259560302256
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.91531768 0.96814622]
# The nwp_inter: 1.1541796383425762
# The total number:
# 2.954144830489576
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.88700074 0.96169825]
# The nwp_inter: 1.1440696124514576
# The total number:
# 2.9320542494303226
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.90240418 0.93728557]
# The nwp_inter: 1.124791271353134
# The total number:
# 2.926736463398292
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.91671337 0.97430347]
# The nwp_inter: 1.1598421809452801
# The total number:
# 2.9648598811974503
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.88988553 0.96928308]
# The nwp_inter: 1.151214420991533
# The total number:
# 2.9492252660072333
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.88997489 0.96528012]
# The nwp_inter: 1.1476970150180121
# The total number:
# 2.932245396411664
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.92686642 0.96352656]
# The nwp_inter: 1.1518710847870721
# The total number:
# 2.953565724285843
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.88455091 0.93898247]
# The nwp_inter: 1.1235701401105926
# The total number:
# 2.9052383827495727
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.88716894 0.94403995]
# The nwp_inter: 1.1284632068772775
# The total number:
# 2.9355395793130286
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.91853794 0.96055463]
# The nwp_inter: 1.1479507145798393
# The total number:
# 2.950341754210746
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87479039 0.96164501]
# The nwp_inter: 1.1421109184314493
# The total number:
# 2.9286830969715383
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.91340924 0.99025063]
# The nwp_inter: 1.1733843776174837
# The total number:
# 2.972273496500204
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.86352594 0.95828494]
# The nwp_inter: 1.1373798044704717
# The total number:
# 2.881127686071062
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.90316366 0.96362062]
# The nwp_inter: 1.1482871986127174
# The total number:
# 2.9235081963251575
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.94516828 0.98281231]
# The nwp_inter: 1.1717936652133805
# The total number:
# 3.0036304962089764
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.9099671  0.96569133]
# The nwp_inter: 1.151176329176736
# The total number:
# 2.9445728733075343
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.94354917 0.96738981]
# The nwp_inter: 1.1578665401438446
# The total number:
# 2.985339022483808
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.91272942 0.966791  ]
# The nwp_inter: 1.1525784144112805
# The total number:
# 2.956518889133265
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.92850284 0.97781098]
# The nwp_inter: 1.1647791096957918
# The total number:
# 2.9837621159374192
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.93540012 0.99027459]
# The nwp_inter: 1.1768649851146444
# The total number:
# 3.0048490983710474
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.93036614 0.98389886]
# The nwp_inter: 1.170449666341061
# The total number:
# 2.9843682454975986
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.89040951 0.95011825]
# The nwp_inter: 1.1343539515322292
# The total number:
# 2.961075304880586
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.91672687 0.9739468 ]
# The nwp_inter: 1.1595290678788084
# The total number:
# 2.9832315505860967
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.96630664 0.99766406]
# The nwp_inter: 1.1882179325230744
# The total number:
# 3.0346013963518614

# %% [markdown]
# # red galaxy

# %% [markdown]
# ## all red galaxy

# %%
r = np.logspace(-2, 2, 21)
r = r[4:]
r_need = 10**((np.log10(r[1:])+np.log10(r[:-1]))/2.0)
# r_need = r_need[4:-2]
number = np.zeros((2,4))

for i in range(len(cen_bin)-1):
    for j in range(len(sate_bin)-1):
        data = np.load("/home/yunzheng/PAC/code/PAC/0_0.2/color_cut_red/%.1f_%.1f.npy"%(cen_bin[i],sate_bin[j]),allow_pickle=True)
        index = np.searchsorted(r,rvir[i])-1
        
        nwp_new = data[1][1:index+1]
        rp_new = np.hstack((r[1:index+1],rvir[i]))
        r_need_new = r_need[1:index+1]
#         print(r_need_new)


        r_inter = (np.log10(rp_new[-1])+np.log10(rp_new[-2]))/2.0
        print("The inter r:",r_inter)

        
        r_need_inter = np.array([np.log10(r_need_new[-2]),np.log10(r_need_new[-1])])
        print("the inter rneed bin:",r_need_inter)

        
        nwp_inter = np.array([np.log10(nwp_new[-2]),np.log10(nwp_new[-1])])
        print("the nwp interbin:",10**nwp_inter)

        
        f = interp1d(r_need_inter,nwp_inter)
        nwp_inter0 = f(r_inter)
        nwp_new = np.hstack((nwp_new[:-1],10**nwp_inter0))
        print("The nwp_inter:",10**nwp_inter0)

        
        print("the nwp_new:")
        print(nwp_new)
        N = np.zeros(len(rp_new)-1)
        print("The number for each bin:")
        for k in range(len(rp_new)-1):
            N[k] = np.pi * (rp_new[k+1]**2-rp_new[k]**2) * nwp_new[k]
            print(N[k])
        print("The total number:")
        print(np.sum(N)) 
        number[i][j] = np.sum(N)
        
np.save("./red_galaxy/original_num2.npy",number)
# Out:
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05307684 0.45726405]
# The nwp_inter: 0.6816677603746577
# the nwp_new:
# [5.14528061 3.27687231 1.99359918 1.05307684 0.68166776]
# The number for each bin:
# 0.2443870036938731
# 0.39095661088048267
# 0.5974573238066573
# 0.7927369515160183
# 0.034223861946860876
# The total number:
# 2.0597617518438924
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01531904 0.9610473 ]
# The nwp_inter: 1.3698498078749533
# the nwp_new:
# [10.80561904  6.81293753  3.70942923  2.01531904  1.36984981]
# The number for each bin:
# 0.5132378704957563
# 0.8128369710892581
# 1.1116706290160419
# 1.517095256077457
# 0.06877478067450232
# The total number:
# 4.023615507353016
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19725442 1.13004347]
# The nwp_inter: 1.5535224103874703
# the nwp_new:
# [10.00368713  6.55889665  3.81302043  2.19725442  1.55352241]
# The number for each bin:
# 0.4751482594517121
# 0.7825278979526106
# 1.1427156472802114
# 1.654052879112124
# 0.07799626092809997
# The total number:
# 4.132440944724759
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11532726 0.54788083]
# The nwp_inter: 0.7699244895927316
# the nwp_new:
# [4.54973091 2.77243192 1.88181315 1.11532726 0.76992449]
# The number for each bin:
# 0.21609999318687606
# 0.3307729087421802
# 0.5639564149872707
# 0.839597932162071
# 0.038654885815410454
# The total number:
# 1.9890821348938084
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.70103481 0.88892378]
# The nwp_inter: 1.0506887350736442
# the nwp_new:
# [7.99340316 4.79554832 2.94578434 1.70103481 1.05068874]
# The number for each bin:
# 0.3796651723272906
# 0.572146589997246
# 0.8828155854310523
# 1.2805078442393245
# 0.7395747629005843
# The total number:
# 3.854709954895498
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.48953299 1.45645248]
# The nwp_inter: 1.8241276607953119
# the nwp_new:
# [19.68382044 10.66704214  6.2190782   3.48953299  1.82412766]
# The number for each bin:
# 0.9349285816097614
# 1.2726619295985386
# 1.8637817707380664
# 2.6268565148935012
# 1.2839947143228212
# The total number:
# 7.982223511162689
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.26468517 1.78435191]
# The nwp_inter: 2.0848250478610177
# the nwp_new:
# [18.54782364 11.12860061  6.58279345  3.26468517  2.08482505]
# The number for each bin:
# 0.8809717862319538
# 1.3277294818299439
# 1.972782789213201
# 2.457595187888326
# 1.4674983551174543
# The total number:
# 8.106577600280879
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.8619646  0.88460295]
# The nwp_inter: 1.0715606406085203
# the nwp_new:
# [6.19256    5.43516932 2.87932974 1.8619646  1.07156064]
# The number for each bin:
# 0.2941299608614682
# 0.6484583998122162
# 0.8628999511902845
# 1.4016528441092662
# 0.7542663971324459
# The total number:
# 3.961407553105681

# %% [markdown]
# ## 修正比例

# %%
r = np.logspace(-2, 2, 21)
r = r[4:]
r_need = 10**((np.log10(r[1:])+np.log10(r[:-1]))/2.0)
number_new = np.zeros((2,4))

for i in range(len(cen_bin)-1):
    for j in range(len(sate_bin)-1):
        nwp = np.load("/home/yunzheng/PAC/code/PAC/0_0.2/color_cut_red/%.1f_%.1f.npy"%(cen_bin[i],sate_bin[j]),allow_pickle=True)
        
        def func_wp(rp,r1,gam):
            y = rp**(1-gam)*r1**gam*gamma(0.5)*gamma(0.5*(gam-1))/gamma(0.5*gam)
            return y
        
        
        popt,pcov = curve_fit(func_wp,nwp[0][1:7],nwp[1][1:7],sigma = nwp[2][1:7],p0=(5,2.05))
        print(popt)
        perr = np.sqrt(np.diag(pcov))
        print(perr)
        
        
        def part_wp1(r,rp0,r1,gam):
            y = 2*r1**gam*r**(1-gam)*(r**2 - rp0**2)**(-0.5)
            return y
        
        def func_wp1(rp,rvir0,r1,gam):
            y = quad(part_wp1,rp,rvir0,args = (rp,r1,gam))
            return y
        

###############calculate ratio###########
        index = np.searchsorted(r,rvir[i])-1
        
        nwp_new = nwp[1][1:index+1]
        rp_new = np.hstack((r[1:index+1],rvir[i]))
        r_need_new = r_need[1:index+1]
#         print(r_need_new)


        r_inter = (np.log10(rp_new[-1])+np.log10(rp_new[-2]))/2.0
        print("The inter r:",r_inter)

        
        r_need_inter = np.array([np.log10(r_need_new[-2]),np.log10(r_need_new[-1])])
        print("the inter rneed bin:",r_need_inter)

        
        nwp_inter = np.array([np.log10(nwp_new[-2]),np.log10(nwp_new[-1])])
        print("the nwp interbin:",10**nwp_inter)

        
        f = interp1d(r_need_inter,nwp_inter)
        nwp_inter0 = f(r_inter)
        nwp_new = np.hstack((nwp_new[:-1],10**nwp_inter0))
        print("The nwp_inter:",10**nwp_inter0)


        N = np.zeros(len(rp_new)-1)
        for k in range(len(rp_new)-1):
            ratio_corr = (func_wp1(rp_new[k],rvir[i],popt[0],popt[1])[0])/func_wp(rp_new[k],popt[0],popt[1])
            print("The corr ratio:")
            print(ratio_corr)
            N[k] = np.pi * (rp_new[k+1]**2-rp_new[k]**2) * nwp_new[k] * ratio_corr

        number_new[i][j] = np.sum(N)
np.save("./red_galaxy/corr_num2.npy",number_new)
# Out:
# [0.43121017 2.32642832]
# [0.01356136 0.09733849]
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05307684 0.45726405]
# The nwp_inter: 0.6816677603746577
# The corr ratio:
# 0.9506054201137155
# The corr ratio:
# 0.9083296031964404
# The corr ratio:
# 0.8277556503318472
# The corr ratio:
# 0.6638158141336783
# The corr ratio:
# 0.15201833952254934
# [0.57838026 2.36299192]
# [0.01673986 0.08618398]
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01531904 0.9610473 ]
# The nwp_inter: 1.3698498078749533
# The corr ratio:
# 0.9542813977681094
# The corr ratio:
# 0.9137003424417584
# The corr ratio:
# 0.8350395981193338
# The corr ratio:
# 0.6722509368417658
# The corr ratio:
# 0.15471919424057493
# [0.5932489  2.22877264]
# [0.01331699 0.06515949]
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19725442 1.13004347]
# The nwp_inter: 1.5535224103874703
# The corr ratio:
# 0.9392217613798699
# The corr ratio:
# 0.8922002539759735
# The corr ratio:
# 0.8065326945132291
# The corr ratio:
# 0.6399594631167616
# The corr ratio:
# 0.1445994753976538
# [0.42436561 2.15522816]
# [0.00987434 0.06294764]
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11532726 0.54788083]
# The nwp_inter: 0.7699244895927316
# The corr ratio:
# 0.928886169259109
# The corr ratio:
# 0.8781020226050936
# The corr ratio:
# 0.7886685377404361
# The corr ratio:
# 0.6206133094838108
# The corr ratio:
# 0.13880015888256328
# [0.53007168 2.24028339]
# [0.0092875  0.05318003]
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.70103481 0.88892378]
# The nwp_inter: 1.0506887350736442
# The corr ratio:
# 0.9539983885621786
# The corr ratio:
# 0.918173768801795
# The corr ratio:
# 0.8533421839965808
# The corr ratio:
# 0.7314075137637182
# The corr ratio:
# 0.4662157467458713
# [0.71809306 2.39433153]
# [0.01516586 0.05547513]
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.48953299 1.45645248]
# The nwp_inter: 1.8241276607953119
# The corr ratio:
# 0.967836532243984
# The corr ratio:
# 0.9385611454054009
# The corr ratio:
# 0.8816799463153746
# The corr ratio:
# 0.7667927922936865
# The corr ratio:
# 0.4981513363955116
# [0.74350429 2.30639182]
# [0.01278117 0.04695339]
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.26468517 1.78435191]
# The nwp_inter: 2.0848250478610177
# The corr ratio:
# 0.9605616397289519
# The corr ratio:
# 0.9276686442597654
# The corr ratio:
# 0.8662991929757118
# The corr ratio:
# 0.747290142820557
# The corr ratio:
# 0.4802863202334111
# [0.52823805 2.10197767]
# [0.0179169  0.08496336]
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.8619646  0.88460295]
# The nwp_inter: 1.0715606406085203
# The corr ratio:
# 0.9363933917787175
# The corr ratio:
# 0.8938763474616002
# The corr ratio:
# 0.8216890603601028
# The corr ratio:
# 0.6943378788612202
# The corr ratio:
# 0.434811114900043

# %% [markdown]
# ## each field

# %%
r = np.logspace(-2, 2, 21)
r = r[4:]
r_need = 10**((np.log10(r[1:])+np.log10(r[:-1]))/2.0)

m_sate = [9.0,9.5,10.0,10.5,11.0]
m_cen = [11.4,11.6,11.8]

jack=50
zs = ['0p075','0p125','0p175']


num0 = np.load("./red_galaxy/original_num2.npy")
num1 = np.load("./red_galaxy/corr_num2.npy")
fq_original = num1/num0


number = np.zeros((2,4,50))
for i in range(len(cen_bin)-1):
    for j in range(len(sate_bin)-1):
        
        pcf = np.zeros((jack,len(r_need)))
        para1 = 0
        for k in range(len(zs)):
            data = np.load('/home/yunzheng/PAC/code/PAC/0_0.2/color_cut_red/%s_%.1f_%.1f_results_jack.npy' % (zs[k],m_cen[i],m_sate[j]))
            para = np.load('/home/yunzheng/PAC/code/PAC/0_0.2/color_cut_red/%s_%.1f_%.1f_param_jack.npy' % (zs[k],m_cen[i],m_sate[j]))


            pcf += (data * para)
            para1 += para

        pcf = pcf/para1
        
        
        for q in range(50):
            
            index = np.searchsorted(r,rvir[i])-1
            print("The index rvir:")
            print(index)
            print(r[index])


        
            nwp_new = pcf[q][1:index+1]
            rp_new = np.hstack((r[1:index+1],rvir[i]))
            r_need_new = r_need[1:index+1]
    #         print(r_need_new)


            r_inter = (np.log10(rp_new[-1])+np.log10(rp_new[-2]))/2.0
            print("The inter r:",r_inter)


            r_need_inter = np.array([np.log10(r_need_new[-2]),np.log10(r_need_new[-1])])
            print("the inter rneed bin:",r_need_inter)


            nwp_inter = np.array([np.log10(nwp_new[-2]),np.log10(nwp_new[-1])])
            print("the nwp interbin:",10**nwp_inter)


            f = interp1d(r_need_inter,nwp_inter)
            nwp_inter0 = f(r_inter)
            nwp_new = np.hstack((nwp_new[:-1],10**nwp_inter0))
            print("The nwp_inter:",10**nwp_inter0)


            N = np.zeros(len(rp_new)-1)
            for p in range(len(rp_new)-1):
                N[p] = np.pi * (rp_new[p+1]**2-rp_new[p]**2) * nwp_new[p] * fq_original[i][j]

            print("The total number:")
            print(np.sum(N))
            
            number[i][j][q] = np.sum(N)
np.save("./red_galaxy/eachfield_result2.npy",number)
# Out:
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.06565471 0.46955154]
# The nwp_inter: 0.6950962827281514
# The total number:
# 1.6375887512841123
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.06059183 0.4523603 ]
# The nwp_inter: 0.6801575841213744
# The total number:
# 1.6302149639503063
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05995056 0.46469949]
# The nwp_inter: 0.6895684753234784
# The total number:
# 1.6316666319340956
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04498026 0.4642412 ]
# The nwp_inter: 0.6845374480732672
# The total number:
# 1.6061794858179625
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04865268 0.45108382]
# The nwp_inter: 0.6754861536651406
# The total number:
# 1.603703200348553
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05071025 0.46170172]
# The nwp_inter: 0.6843715088132574
# The total number:
# 1.623379704919081
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.06466258 0.47069298]
# The nwp_inter: 0.6956665292364791
# The total number:
# 1.6245739199941391
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04720611 0.45385942]
# The nwp_inter: 0.6772023913595189
# The total number:
# 1.6080550450878874
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05379581 0.45135805]
# The nwp_inter: 0.6772843837525769
# The total number:
# 1.6152481731832535
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04731816 0.44367581]
# The nwp_inter: 0.6692715203713309
# The total number:
# 1.601241372325879
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.06252673 0.45599614]
# The nwp_inter: 0.6835984142385483
# The total number:
# 1.6259002725302427
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04037611 0.45289414]
# The nwp_inter: 0.6743357998884837
# The total number:
# 1.609525428255408
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04239822 0.45036199]
# The nwp_inter: 0.6729926747794446
# The total number:
# 1.600492981877228
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05461792 0.45613556]
# The nwp_inter: 0.6812668172253852
# The total number:
# 1.6084857129394923
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04255389 0.45293078]
# The nwp_inter: 0.6750395274199399
# The total number:
# 1.602830405842384
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.03794634 0.45442495]
# The nwp_inter: 0.674767603894933
# The total number:
# 1.5925440402439912
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04933497 0.4491899 ]
# The nwp_inter: 0.6742158795704883
# The total number:
# 1.6002364566360443
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04992873 0.45894247]
# The nwp_inter: 0.6819931385514337
# The total number:
# 1.6027674917517951
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04887662 0.4508488 ]
# The nwp_inter: 0.6753716628436197
# The total number:
# 1.6119497812755903
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05055998 0.44917581]
# The nwp_inter: 0.6745814588596741
# The total number:
# 1.599486592238715
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05539101 0.45269593]
# The nwp_inter: 0.6788215919609962
# The total number:
# 1.6114541384398884
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05292755 0.46129063]
# The nwp_inter: 0.6847442946514246
# The total number:
# 1.6134964518411299
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05572804 0.45248317]
# The nwp_inter: 0.6787589630406176
# The total number:
# 1.6124012497441913
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.03522407 0.46271274]
# The nwp_inter: 0.680300326225514
# The total number:
# 1.5928175659680657
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04641132 0.4567567 ]
# The nwp_inter: 0.6792059674986561
# The total number:
# 1.601845187812619
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05330253 0.45704024]
# The nwp_inter: 0.6815636871081163
# The total number:
# 1.6063093468756433
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.06434941 0.46275818]
# The nwp_inter: 0.6894303293480183
# The total number:
# 1.6227796518696413
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.06508139 0.45754608]
# The nwp_inter: 0.6855964408305453
# The total number:
# 1.6234100695652944
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04935394 0.46044445]
# The nwp_inter: 0.6829768605302117
# The total number:
# 1.6090419942245655
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.03515596 0.4493418 ]
# The nwp_inter: 0.6699580251300878
# The total number:
# 1.5982011635074482
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05239334 0.46068509]
# The nwp_inter: 0.6841093237384439
# The total number:
# 1.5985621385341333
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05259221 0.4605139 ]
# The nwp_inter: 0.6840386328025854
# The total number:
# 1.6157784784417477
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04222325 0.45577519]
# The nwp_inter: 0.677143607331745
# The total number:
# 1.5976953399575686
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.0584162  0.46152228]
# The nwp_inter: 0.6866301234114001
# The total number:
# 1.6241759019383313
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05440936 0.45871223]
# The nwp_inter: 0.6832058653120803
# The total number:
# 1.6097338525234273
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.06241018 0.46877496]
# The nwp_inter: 0.6934838096097765
# The total number:
# 1.6274556402727236
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04999201 0.45592486]
# The nwp_inter: 0.6796711516380909
# The total number:
# 1.6120452366584406
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.071584   0.46250869]
# The nwp_inter: 0.6914748954760537
# The total number:
# 1.6201424400209148
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04415    0.44765789]
# The nwp_inter: 0.6714222728545765
# The total number:
# 1.6002798948247523
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.0532261  0.45295228]
# The nwp_inter: 0.6783549459433
# The total number:
# 1.6096837746893915
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05177606 0.45132622]
# The nwp_inter: 0.6766378664631829
# The total number:
# 1.6173733050229313
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04684302 0.45121161]
# The nwp_inter: 0.6750276463961887
# The total number:
# 1.6064665402157463
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04344847 0.44299152]
# The nwp_inter: 0.6675493650354356
# The total number:
# 1.593392527560666
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.06062516 0.46516584]
# The nwp_inter: 0.6901393143678667
# The total number:
# 1.6180720795201435
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.04122321 0.45952804]
# The nwp_inter: 0.6797324383008875
# The total number:
# 1.6071226474274805
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.05356439 0.45656403]
# The nwp_inter: 0.6812744021739228
# The total number:
# 1.6255465478869828
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.02858865 0.44196591]
# The nwp_inter: 0.6621814588240129
# The total number:
# 1.5763783426459097
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.09333601 0.4793817 ]
# The nwp_inter: 0.7113231226821679
# The total number:
# 1.6675933648546521
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.08860689 0.47619952]
# The nwp_inter: 0.707388202581508
# The total number:
# 1.6612049896490604
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.06886564 0.46664603]
# The nwp_inter: 0.6938489110895749
# The total number:
# 1.654232999209362
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.03339903 0.99545598]
# The nwp_inter: 1.4011819854620273
# The total number:
# 3.232454208553221
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00123074 0.97573959]
# The nwp_inter: 1.3761003075074116
# The total number:
# 3.20574496179356
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.06495158 0.98009801]
# The nwp_inter: 1.4001505740243527
# The total number:
# 3.2366198732556057
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00836908 0.9646661 ]
# The nwp_inter: 1.3702691143596222
# The total number:
# 3.1760873563598415
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.02030062 0.95371006]
# The nwp_inter: 1.366000393647501
# The total number:
# 3.191810840267428
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.06748404 0.98467022]
# The nwp_inter: 1.4043758434472164
# The total number:
# 3.244437695280602
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.03414354 0.96937402]
# The nwp_inter: 1.3821619428771887
# The total number:
# 3.202801946489084
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01035363 0.96726081]
# The nwp_inter: 1.3728382880072376
# The total number:
# 3.1784590898043477
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.98365837 0.94014924]
# The nwp_inter: 1.3440128988106173
# The total number:
# 3.163378550717299
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.98867415 0.92974628]
# The nwp_inter: 1.3378547181671947
# The total number:
# 3.161036897510409
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01373845 0.96444751]
# The nwp_inter: 1.3718592318166383
# The total number:
# 3.2000666338743122
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.02731255 0.96409043]
# The nwp_inter: 1.3760118880088412
# The total number:
# 3.19707181932292
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.0139179  0.95459503]
# The nwp_inter: 1.3645928074651863
# The total number:
# 3.1790990401073453
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01573743 0.95466099]
# The nwp_inter: 1.3652319492126899
# The total number:
# 3.1921350683462055
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.99498379 0.94639774]
# The nwp_inter: 1.3523427281491562
# The total number:
# 3.1529010296395694
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.0080457  0.97307971]
# The nwp_inter: 1.3763810251292008
# The total number:
# 3.1733166591874995
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01142205 0.95370837]
# The nwp_inter: 1.3631225330152352
# The total number:
# 3.178274010653917
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01643851 0.95846331]
# The nwp_inter: 1.3682919425168525
# The total number:
# 3.1851088620247796
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.0069692  0.96517383]
# The nwp_inter: 1.3701877285547255
# The total number:
# 3.18063402564786
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01304242 0.96233111]
# The nwp_inter: 1.37006215440273
# The total number:
# 3.178056104115622
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00645885 0.96022727]
# The nwp_inter: 1.366355712525132
# The total number:
# 3.1730740813977127
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01228047 0.96602417]
# The nwp_inter: 1.372552136186344
# The total number:
# 3.19013980059378
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00549359 0.94595788]
# The nwp_inter: 1.3554194349308637
# The total number:
# 3.1821193393182012
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.99655832 0.96396048]
# The nwp_inter: 1.365885053388786
# The total number:
# 3.1654627538846283
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00767537 0.96269774]
# The nwp_inter: 1.3685843551947035
# The total number:
# 3.1834370648022805
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00631537 0.96312317]
# The nwp_inter: 1.3684557308040994
# The total number:
# 3.171528085815364
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00894216 0.95576715]
# The nwp_inter: 1.3638503507735797
# The total number:
# 3.1872861802075816
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01745437 0.95526739]
# The nwp_inter: 1.366240645494761
# The total number:
# 3.189471087502226
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.0227371  0.96090993]
# The nwp_inter: 1.3721585905067128
# The total number:
# 3.204697652809516
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.99220109 0.95590407]
# The nwp_inter: 1.3585000995480725
# The total number:
# 3.1713421335553464
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.02378709 0.9568142 ]
# The nwp_inter: 1.3694463231786083
# The total number:
# 3.184194159871723
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.03443577 0.965856  ]
# The nwp_inter: 1.3796393023185634
# The total number:
# 3.2102159242366684
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00092979 0.94852215]
# The nwp_inter: 1.3558545144230816
# The total number:
# 3.1760311505683854
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.02519267 0.96760398]
# The nwp_inter: 1.377933962271568
# The total number:
# 3.203560567115142
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01384551 0.94865291]
# The nwp_inter: 1.3601341704637382
# The total number:
# 3.1824569953189545
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.0100046  0.96064118]
# The nwp_inter: 1.367818179240508
# The total number:
# 3.193754658935461
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01828981 0.94654641]
# The nwp_inter: 1.3599929036835887
# The total number:
# 3.1961823887774563
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01122331 0.96173952]
# The nwp_inter: 1.369030438426287
# The total number:
# 3.1874884143534463
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01036825 0.94897567]
# The nwp_inter: 1.359250635398502
# The total number:
# 3.1898247616935285
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.97111276 0.94216151]
# The nwp_inter: 1.3414321883142788
# The total number:
# 3.1589607308578525
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.01969391 0.95443217]
# The nwp_inter: 1.3663430958355542
# The total number:
# 3.177959837652773
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.99471529 0.95413789]
# The nwp_inter: 1.3580104057858566
# The total number:
# 3.158567610472331
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.97198632 0.92487605]
# The nwp_inter: 1.328825919133955
# The total number:
# 3.133352124337984
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.04010347 0.97716448]
# The nwp_inter: 1.3898870398028285
# The total number:
# 3.2012289597864383
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.04462645 0.96033818]
# The nwp_inter: 1.3788179631958113
# The total number:
# 3.2079375738899105
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00020968 0.95877613]
# The nwp_inter: 1.3632418589293644
# The total number:
# 3.1969082488748706
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.00930887 0.95789282]
# The nwp_inter: 1.365550241311116
# The total number:
# 3.1850989479504235
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.06308381 0.98033999]
# The nwp_inter: 1.3997244082571312
# The total number:
# 3.264425676091416
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.03244499 0.98050221]
# The nwp_inter: 1.3898559820041336
# The total number:
# 3.249335736162648
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.06030025 1.00873404]
# The nwp_inter: 1.4197987922098514
# The total number:
# 3.277490660437204
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.23260328 1.15816544]
# The nwp_inter: 1.5856263438980993
# The total number:
# 3.1849662565749743
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19928867 1.14507498]
# The nwp_inter: 1.5649551064937142
# The total number:
# 3.151159779513077
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21596607 1.16947714]
# The nwp_inter: 1.5879864450891756
# The total number:
# 3.155843328289855
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19486015 1.13887987]
# The nwp_inter: 1.5590302834733336
# The total number:
# 3.1357169745046125
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19586074 1.12109933]
# The nwp_inter: 1.5466297774249864
# The total number:
# 3.1245908211138915
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22719437 1.14149253]
# The nwp_inter: 1.5718580511331646
# The total number:
# 3.1727758921716527
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18346767 1.13002017]
# The nwp_inter: 1.548832555566058
# The total number:
# 3.1220683911363745
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18139362 1.12386966]
# The nwp_inter: 1.5437293330961441
# The total number:
# 3.120648339167779
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.16779146 1.11966993]
# The nwp_inter: 1.536113209188438
# The total number:
# 3.113053256195808
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18338839 1.11028626]
# The nwp_inter: 1.5346446476002649
# The total number:
# 3.1199479998501825
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.21628849 1.13918216]
# The nwp_inter: 1.5665137439072703
# The total number:
# 3.143317080613904
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20591331 1.13740096]
# The nwp_inter: 1.561724820187771
# The total number:
# 3.1400271289344346
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20029339 1.12355092]
# The nwp_inter: 1.5498874396070528
# The total number:
# 3.128695076464304
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.1921974  1.12844263]
# The nwp_inter: 1.5506635207320643
# The total number:
# 3.13504262172012
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.16401705 1.11410754]
# The nwp_inter: 1.530852398864468
# The total number:
# 3.1014235074519063
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18860247 1.13486673]
# The nwp_inter: 1.5540385176649707
# The total number:
# 3.1250320192672754
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18684799 1.12945937]
# The nwp_inter: 1.549578675944394
# The total number:
# 3.1241278448183425
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18021248 1.1162469 ]
# The nwp_inter: 1.5378627578556698
# The total number:
# 3.1160536548871622
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20038085 1.13668784]
# The nwp_inter: 1.5593389008970493
# The total number:
# 3.1281493919735617
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18340805 1.13723048]
# The nwp_inter: 1.553956867893152
# The total number:
# 3.1213240951237644
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19054597 1.13489787]
# The nwp_inter: 1.5547211230114841
# The total number:
# 3.120377417431068
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18809521 1.12924306]
# The nwp_inter: 1.549846835677742
# The total number:
# 3.1229566962077735
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.1950571 1.1187777]
# The nwp_inter: 1.5446884445470364
# The total number:
# 3.1235375563494716
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.1875509  1.12817346]
# The nwp_inter: 1.5488968501251974
# The total number:
# 3.1203496056533715
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18191133 1.13300823]
# The nwp_inter: 1.5504372334918104
# The total number:
# 3.1181617261048094
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20337157 1.11587654]
# The nwp_inter: 1.5453926906975017
# The total number:
# 3.146739819394553
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19813168 1.12119379]
# The nwp_inter: 1.547463130823467
# The total number:
# 3.1378047718106843
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18017816 1.11230874]
# The nwp_inter: 1.535020061707938
# The total number:
# 3.1226157749925916
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19920665 1.12616073]
# The nwp_inter: 1.551396489892553
# The total number:
# 3.136749829323503
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.17667001 1.11404823]
# The nwp_inter: 1.5350874611458332
# The total number:
# 3.1166101961677293
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20089622 1.12622483]
# The nwp_inter: 1.552012904042152
# The total number:
# 3.1294584295698793
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22756054 1.14126767]
# The nwp_inter: 1.5718202825601217
# The total number:
# 3.1513303420612697
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18902142 1.12550186]
# The nwp_inter: 1.5474811018414822
# The total number:
# 3.1282107984324794
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20175178 1.13337359]
# The nwp_inter: 1.5574310441704546
# The total number:
# 3.14626158067299
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18447374 1.11567196]
# The nwp_inter: 1.538887280207382
# The total number:
# 3.1123176454551267
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19113812 1.1291955 ]
# The nwp_inter: 1.5508440221897655
# The total number:
# 3.1404621906710584
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.18467302 1.13417623]
# The nwp_inter: 1.5522098114300276
# The total number:
# 3.1261378455093025
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.17235847 1.11406688]
# The nwp_inter: 1.5336447193265121
# The total number:
# 3.11118823281002
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19442489 1.13230059]
# The nwp_inter: 1.5541805571417997
# The total number:
# 3.1331699067519
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20417787 1.11995235]
# The nwp_inter: 1.5486042208093476
# The total number:
# 3.1421043617465294
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.17474957 1.10574717]
# The nwp_inter: 1.5284673482567415
# The total number:
# 3.101331497904052
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.17033759 1.13826049]
# The nwp_inter: 1.5502289865138659
# The total number:
# 3.112580048621623
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.16587287 1.08836073]
# The nwp_inter: 1.5129250851249945
# The total number:
# 3.0964913740287683
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.22044457 1.13940158]
# The nwp_inter: 1.5680765332610047
# The total number:
# 3.169380069340106
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.19630189 1.1187074 ]
# The nwp_inter: 1.5450570313624021
# The total number:
# 3.133366654499806
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20507941 1.13752539]
# The nwp_inter: 1.5615312787657076
# The total number:
# 3.1552736538343327
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.20778293 1.14096967]
# The nwp_inter: 1.5649120706077693
# The total number:
# 3.139278312220876
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.24168348 1.14337404]
# The nwp_inter: 1.5780986489683118
# The total number:
# 3.185169879725054
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.26899917 1.15448134]
# The nwp_inter: 1.5952942030650865
# The total number:
# 3.2109804348034827
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [2.26029914 1.17471524]
# The nwp_inter: 1.6068535265696418
# The total number:
# 3.2397957078153152
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11774948 0.54644597]
# The nwp_inter: 0.7696713346389352
# The total number:
# 1.476402474545693
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.12510792 0.55561425]
# The nwp_inter: 0.7788193756571421
# The total number:
# 1.4742835946831807
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.12653664 0.55989429]
# The nwp_inter: 0.7824166391498306
# The total number:
# 1.476785912308412
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.09736241 0.54367889]
# The nwp_inter: 0.7609032469870944
# The total number:
# 1.4521615437282283
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10298002 0.54238313]
# The nwp_inter: 0.7618168089882594
# The total number:
# 1.456463630266664
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.12305701 0.55341944]
# The nwp_inter: 0.7765354357042026
# The total number:
# 1.4710959217983668
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.1186676  0.55295579]
# The nwp_inter: 0.7747426547790929
# The total number:
# 1.4633021196358402
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10953003 0.55076735]
# The nwp_inter: 0.7701133716065671
# The total number:
# 1.4662776625899134
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10647278 0.5381815 ]
# The nwp_inter: 0.7598832817484102
# The total number:
# 1.4519564612158422
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11733014 0.54047668]
# The nwp_inter: 0.765138854060924
# The total number:
# 1.4617041391104764
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11530798 0.54751353]
# The nwp_inter: 0.7696489718082038
# The total number:
# 1.4658178919454599
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11831    0.55583281]
# The nwp_inter: 0.7767227835493423
# The total number:
# 1.4657098765213752
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.12253873 0.54652819]
# The nwp_inter: 0.7713085277555772
# The total number:
# 1.462225933323614
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.1287639  0.54719203]
# The nwp_inter: 0.7738424820609491
# The total number:
# 1.4722192991832312
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11430038 0.53720931]
# The nwp_inter: 0.7617331478890249
# The total number:
# 1.4555424437657776
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10597702 0.54783869]
# The nwp_inter: 0.7667975774403881
# The total number:
# 1.4528732395811508
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10963768 0.53708065]
# The nwp_inter: 0.7601109495209916
# The total number:
# 1.457278600182284
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10472323 0.54073857]
# The nwp_inter: 0.7611867568244131
# The total number:
# 1.4550789845689966
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.12677902 0.54555834]
# The nwp_inter: 0.7719864714526857
# The total number:
# 1.4664461923774694
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.12236831 0.54983314]
# The nwp_inter: 0.7736805687045238
# The total number:
# 1.4627133814289508
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11343204 0.54746926]
# The nwp_inter: 0.7689966695874418
# The total number:
# 1.4572292155623585
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.12207323 0.55206701]
# The nwp_inter: 0.7752202315658829
# The total number:
# 1.4648120171846792
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11190309 0.54175852]
# The nwp_inter: 0.764301170411008
# The total number:
# 1.4604432737661737
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11593074 0.54476938]
# The nwp_inter: 0.7678405126437846
# The total number:
# 1.4610358661048688
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11180786 0.54483854]
# The nwp_inter: 0.7665321260971074
# The total number:
# 1.4554015016056239
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11714102 0.54532654]
# The nwp_inter: 0.7686485326613473
# The total number:
# 1.4590406907804174
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10924635 0.54028928]
# The nwp_inter: 0.7623464129352627
# The total number:
# 1.457094178772276
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10197771 0.54411081]
# The nwp_inter: 0.7627490396140518
# The total number:
# 1.4496173237083199
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11654333 0.54523266]
# The nwp_inter: 0.7683826918799175
# The total number:
# 1.4636762540412749
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10255051 0.54159727]
# The nwp_inter: 0.7610992233035695
# The total number:
# 1.4518194679772045
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11420229 0.54681407]
# The nwp_inter: 0.7687711345430063
# The total number:
# 1.4609730602344508
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.12941355 0.55210775]
# The nwp_inter: 0.7776733193119464
# The total number:
# 1.4739076170450007
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11301959 0.54885614]
# The nwp_inter: 0.7698751737602738
# The total number:
# 1.4524204305039863
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11604499 0.55233351]
# The nwp_inter: 0.7734185930408324
# The total number:
# 1.4621209463882232
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10382632 0.54119043]
# The nwp_inter: 0.7612223338325123
# The total number:
# 1.4556192786965747
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11393494 0.55227577]
# The nwp_inter: 0.772676241966747
# The total number:
# 1.4677467017506376
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.12167474 0.55517358]
# The nwp_inter: 0.7773593512609093
# The total number:
# 1.4687977403864032
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.09630444 0.54370499]
# The nwp_inter: 0.7605710710186087
# The total number:
# 1.444414445213007
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10495444 0.54960065]
# The nwp_inter: 0.7677423817398771
# The total number:
# 1.453097311334807
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11078981 0.54603565]
# The nwp_inter: 0.7670733445865142
# The total number:
# 1.4543974458737856
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10470198 0.55032466]
# The nwp_inter: 0.768185486891395
# The total number:
# 1.4491890963935175
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10692949 0.54266491]
# The nwp_inter: 0.7633279102018378
# The total number:
# 1.4521824239455194
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.09852962 0.53321588]
# The nwp_inter: 0.7536165079163758
# The total number:
# 1.4430805563228781
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.13258896 0.55647789]
# The nwp_inter: 0.7819266314406401
# The total number:
# 1.4722235593863175
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.10132484 0.54527386]
# The nwp_inter: 0.7633820747610418
# The total number:
# 1.4514057156209683
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11202921 0.54752737]
# The nwp_inter: 0.7685753144012615
# The total number:
# 1.466332328650271
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.11574969 0.54633368]
# The nwp_inter: 0.7689295375294309
# The total number:
# 1.4608235641138594
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.147056  0.5629589]
# The nwp_inter: 0.7914549700295119
# The total number:
# 1.4923360208297782
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.13125548 0.55097497]
# The nwp_inter: 0.7774471654548456
# The total number:
# 1.4869222198472518
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.19572677049206816
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.15592661 0.58359478]
# The nwp_inter: 0.8094293616218643
# The total number:
# 1.505000612981538
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.72762197 0.90143978]
# The nwp_inter: 1.0659017076019472
# The total number:
# 2.9746524077600016
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.7132464  0.87728215]
# The nwp_inter: 1.0423752684808105
# The total number:
# 2.910209205354679
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.72241757 0.91392843]
# The nwp_inter: 1.0760084482242898
# The total number:
# 2.9660428840107973
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.70796888 0.91383971]
# The nwp_inter: 1.0735984730825114
# The total number:
# 2.939283935887553
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.73112563 0.9049017 ]
# The nwp_inter: 1.06949721645556
# The total number:
# 2.955564678746116
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.70876644 0.8843746 ]
# The nwp_inter: 1.047917853786518
# The total number:
# 2.925140330553067
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.74700207 0.92978781]
# The nwp_inter: 1.093825735115994
# The total number:
# 2.9774114587262743
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.6686424  0.86979791]
# The nwp_inter: 1.0287511286065731
# The total number:
# 2.8932729846187173
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.73254516 0.89341379]
# The nwp_inter: 1.0596247011088813
# The total number:
# 2.9688960063196106
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.66806002 0.89201989]
# The nwp_inter: 1.0481053250713468
# The total number:
# 2.902471342517811
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.66323024 0.85895862]
# The nwp_inter: 1.0183656857252754
# The total number:
# 2.8595614340256237
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.70799721 0.89323591]
# The nwp_inter: 1.0555803772154344
# The total number:
# 2.9317619996480433
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.66050162 0.91630448]
# The nwp_inter: 1.0679646721933587
# The total number:
# 2.9255711829599234
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.63628511 0.88124515]
# The nwp_inter: 1.033558295840646
# The total number:
# 2.8760367479792794
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.61810996 0.84813412]
# The nwp_inter: 1.0017004059778913
# The total number:
# 2.816707394027869
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.69447501 0.87153111]
# The nwp_inter: 1.0343581606793146
# The total number:
# 2.909987863433947
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.70976814 0.88585088]
# The nwp_inter: 1.049374620512171
# The total number:
# 2.9275686321332985
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.70740583 0.87553326]
# The nwp_inter: 1.0399169427339094
# The total number:
# 2.9098847492029165
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.63934598 0.84799971]
# The nwp_inter: 1.0049525147149339
# The total number:
# 2.8422410013989063
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.72320916 0.88198926]
# The nwp_inter: 1.0480889076135007
# The total number:
# 2.9250290565938903
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.68609237 0.86976214]
# The nwp_inter: 1.0314804686280183
# The total number:
# 2.8878127085262273
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.69113598 0.88443356]
# The nwp_inter: 1.0451734597228841
# ...
# The nwp_inter: 2.0562469523372835
# The total number:
# 6.2586591187988745
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.30069906 1.76293413]
# The nwp_inter: 2.072066605710742
# The total number:
# 6.372064430549507
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.207543   1.72256431]
# The nwp_inter: 2.0217702111318783
# The total number:
# 6.2258986639471035
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.15902913 1.78480295]
# The nwp_inter: 2.0676181152234565
# The total number:
# 6.202220814203713
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.32623343 1.811632  ]
# The nwp_inter: 2.1186107516387636
# The total number:
# 6.383155228551895
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.26733682 1.80812351]
# The nwp_inter: 2.1058495946238955
# The total number:
# 6.354705011004789
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.22553319 1.78047627]
# The nwp_inter: 2.0750028663865807
# The total number:
# 6.311200620417435
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.27534031 1.78491227]
# The nwp_inter: 2.087062300810938
# The total number:
# 6.313197579276515
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.2641924 1.777908 ]
# The nwp_inter: 2.079152184862898
# The total number:
# 6.283107100352619
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.2394649  1.76388583]
# The nwp_inter: 2.0629209711615846
# The total number:
# 6.281776031752619
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.19739104 1.76253476]
# The nwp_inter: 2.0548158316205183
# The total number:
# 6.221470984958513
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.2110496  1.72889126]
# The nwp_inter: 2.0278511982873493
# The total number:
# 6.2508894892853615
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.28651225 1.84237257]
# The nwp_inter: 2.1386119252121447
# The total number:
# 6.375500995142859
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.21002595 1.77433204]
# The nwp_inter: 2.0671166262933567
# The total number:
# 6.272430854121807
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.24816886 1.79270908]
# The nwp_inter: 2.0893378798587694
# The total number:
# 6.31270327398188
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.31614113 1.83388878]
# The nwp_inter: 2.1362301582650636
# The total number:
# 6.430106566741994
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.21165957 1.78198738]
# The nwp_inter: 2.07400574418443
# The total number:
# 6.27129450223083
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.31564415 1.81125237]
# The nwp_inter: 2.1165417950454786
# The total number:
# 6.392716779769962
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.27384569 1.80218694]
# The nwp_inter: 2.10179182866987
# The total number:
# 6.348828905970467
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.2663569  1.84288478]
# The nwp_inter: 2.1356660735135566
# The total number:
# 6.409964466250772
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.26469916 1.7754976 ]
# The nwp_inter: 2.0771422547591594
# The total number:
# 6.3902060833573335
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.27570893 1.82341984]
# The nwp_inter: 2.12045826907071
# The total number:
# 6.378730639842734
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.34923258 1.79963531]
# The nwp_inter: 2.1119323100697507
# The total number:
# 6.425356381548083
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.30232741 1.79873803]
# The nwp_inter: 2.1034938236791825
# The total number:
# 6.373500478298915
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [3.41490102 1.8072111 ]
# The nwp_inter: 2.1291528049883484
# The total number:
# 6.563151272490217
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.93363266 0.90542569]
# The nwp_inter: 1.1008894275595047
# The total number:
# 2.92851888296646
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.84665381 0.87693861]
# The nwp_inter: 1.0623982593597012
# The total number:
# 2.8417344267255746
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.88234437 0.88185998]
# The nwp_inter: 1.072095331637578
# The total number:
# 2.878773631480318
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.85849308 0.8985971 ]
# The nwp_inter: 1.0835987603990618
# The total number:
# 2.8846948046930634
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87214372 0.88692779]
# The nwp_inter: 1.0751596561304864
# The total number:
# 2.887786544719438
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87487824 0.89961852]
# The nwp_inter: 1.0869682193951073
# The total number:
# 2.8818816361793997
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.89513098 0.87984335]
# The nwp_inter: 1.0721429877121527
# The total number:
# 2.8920607046670828
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.894617   0.89534368]
# The nwp_inter: 1.0860576752830795
# The total number:
# 2.895496532949297
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.88310887 0.89405274]
# The nwp_inter: 1.0831934591768158
# The total number:
# 2.9036712125108473
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.84981749 0.86524956]
# The nwp_inter: 1.0523311116379617
# The total number:
# 2.8499681465423317
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.82663485 0.87579682]
# The nwp_inter: 1.0583950192411207
# The total number:
# 2.852868443093624
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.89170351 0.90907176]
# The nwp_inter: 1.0979603441610046
# The total number:
# 2.9034729544969315
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.84652006 0.89302387]
# The nwp_inter: 1.0768110692832122
# The total number:
# 2.8695477727443146
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.86156335 0.86824993]
# The nwp_inter: 1.056760723807682
# The total number:
# 2.8151941000803697
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.85596461 0.87808164]
# The nwp_inter: 1.064804828035899
# The total number:
# 2.848285987550125
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87243522 0.89023869]
# The nwp_inter: 1.0781810674289838
# The total number:
# 2.8596579664896464
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.82244357 0.87085377]
# The nwp_inter: 1.0533335226757286
# The total number:
# 2.8469026559327633
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87187815 0.88007995]
# The nwp_inter: 1.068951829376086
# The total number:
# 2.8626000849347983
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.84081878 0.87012636]
# The nwp_inter: 1.0554044520368924
# The total number:
# 2.8318221163500423
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87307189 0.88803466]
# The nwp_inter: 1.0762930355945497
# The total number:
# 2.8750795537598286
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87879103 0.89824017]
# The nwp_inter: 1.0863148910848552
# The total number:
# 2.878412898286463
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.84175759 0.85193799]
# The nwp_inter: 1.0391185736216086
# The total number:
# 2.8260962679600743
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.8973249  0.88429085]
# The nwp_inter: 1.0764845581069347
# The total number:
# 2.885562329832183
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.84771429 0.91321811]
# The nwp_inter: 1.0950184595800434
# The total number:
# 2.8649774829173014
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.83342755 0.88327915]
# The nwp_inter: 1.0661194914804697
# The total number:
# 2.839259982037578
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.85602214 0.85079025]
# The nwp_inter: 1.0401444523071284
# The total number:
# 2.8474614669911555
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.86003931 0.8838456 ]
# The nwp_inter: 1.0705941322008372
# The total number:
# 2.8651102633109646
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.83256146 0.87890475]
# The nwp_inter: 1.0620679984393202
# The total number:
# 2.8378393284105163
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.84387413 0.86042833]
# The nwp_inter: 1.0471064503805745
# The total number:
# 2.8311347886164167
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.8622641  0.89139922]
# The nwp_inter: 1.0777110221563364
# The total number:
# 2.869694324403432
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.83149297 0.8868493 ]
# The nwp_inter: 1.0690260998312633
# The total number:
# 2.8518802471653233
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.83633511 0.88060403]
# The nwp_inter: 1.0641558310588306
# The total number:
# 2.83781931712696
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87759371 0.87583619]
# The nwp_inter: 1.0659597288284866
# The total number:
# 2.857086518692178
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.8355585  0.85946065]
# The nwp_inter: 1.0450144978701745
# The total number:
# 2.815625726931107
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.83649942 0.8644831 ]
# The nwp_inter: 1.049683221161768
# The total number:
# 2.8463418095699735
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.86582633 0.87725589]
# The nwp_inter: 1.0655150527187163
# The total number:
# 2.855797586941822
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.82611604 0.88290657]
# The nwp_inter: 1.0646890614239575
# The total number:
# 2.8382792696121233
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.85735918 0.90441108]
# The nwp_inter: 1.088628058333985
# The total number:
# 2.8758410771726304
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.80941961 0.87704092]
# The nwp_inter: 1.0569294948768566
# The total number:
# 2.7901319154557873
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.84991498 0.88184285]
# The nwp_inter: 1.067290912078063
# The total number:
# 2.835668572037494
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.89048588 0.90201823]
# The nwp_inter: 1.0914485054934264
# The total number:
# 2.9074429032923046
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.86531943 0.88131131]
# The nwp_inter: 1.0690947988609394
# The total number:
# 2.855616727570763
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.89280755 0.88463257]
# The nwp_inter: 1.0761323129700442
# The total number:
# 2.894113178916176
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.85664884 0.89441939]
# The nwp_inter: 1.079580378862446
# The total number:
# 2.8619313745968507
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87606496 0.89701216]
# The nwp_inter: 1.0848063000673056
# The total number:
# 2.8890556892284383
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.87783914 0.90490153]
# The nwp_inter: 1.0921473155471701
# The total number:
# 2.906238188558827
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.88874339 0.89838197]
# The nwp_inter: 1.087921924244137
# The total number:
# 2.894146643681694
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.83429041 0.86973127]
# The nwp_inter: 1.0540834713281562
# The total number:
# 2.867999156519208
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.86541358 0.8875819 ]
# The nwp_inter: 1.0747506639262627
# The total number:
# 2.8825055423308834
# The index rvir:
# 5
# 0.6309573444801934
# The inter r: -0.1515237851416182
# the inter rneed bin: [-0.3 -0.1]
# the nwp interbin: [1.91687038 0.91571739]
# The nwp_inter: 1.1076783617631
# The total number:
# 2.9444839136575567

# %% [markdown]
# # result

# %%
red_num = np.load("./red_galaxy/eachfield_result2.npy")
all_num = np.load("./all/eachfield_result2.npy")

# %%
result = np.mean(red_num / all_num,axis = 2)

# %%
result
# Out:
# array([[0.61449175, 0.80117796, 0.89590143, 0.94888908],
#        [0.62639007, 0.83779117, 0.91166904, 0.96849947]])

# %%
sigma = np.sqrt(49) * np.std(red_num / all_num,axis = -1)

# %%
np.save("./result2.npy",np.array([result,sigma]))

# %%
cen_bin = [11.3, 11.5, 11.7]
sate_bin = [9.0, 9.5, 10.0, 10.5,11.0]
color0 = ['cornflowerblue','orange']   #######e','seagreen',
for i in range(2):
    for j in range(4):
       
        if j==3:
            continue
        data = np.load("./result2.npy")
        plt.errorbar(sate_bin[j],data[0][i][j],data[1][i][j],color = color0[i],fmt = 'o')
plt.errorbar(sate_bin[-2],data[0][1][3],data[1][1][3],color = color0[1],fmt = 'o',label = "$Spec : %s M_{\odot}$"%cen_bin[1])
plt.errorbar(sate_bin[3],data[0][0][3],data[1][0][3],color = color0[0],fmt = 'o',label = "$Spec : %s M_{\odot}$"%cen_bin[0])

TNG = np.load("./TNG_fq.npz")
plt.plot(sate_bin[:-1],TNG['version2'][0],color = color0[0],linestyle = '-.',label = "$TNG : 11.3 M_{\odot}$")
plt.plot(sate_bin[:-1],TNG['version2'][1],color = color0[1],linestyle = '-.',label = "$TNG : 11.5 M_{\odot}$")


plt.xlabel("$log(Sat mass)$")
plt.ylabel("$Fq$")
plt.legend(loc = "upper left")
plt.title("$Z = 0.0 - 0.2$")
plt.ylim(0.45,1.02)
# plt.plot()
# plt.savefig("/home/yunzheng/PAC/picture/PCF_colorcut/Fq_0.3.pdf",dpi = 100)
# Out:
# (0.45, 1.02)
